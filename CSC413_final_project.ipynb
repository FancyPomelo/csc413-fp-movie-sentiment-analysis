# %% [markdown]
# **Data process** (code from A1)

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

from nltk.stem import PorterStemmer
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords

# %% [markdown]
# # Download data to txt file

# %%
import os

# plz edit path
file_path = "/Users/wangzeyang/Desktop/CSC413/A2/aclImdb/test/neg" 
file_path_pos = "/Users/wangzeyang/Desktop/CSC413/A2/aclImdb/test/pos"

lst = os.listdir(file_path)
lst_2 = os.listdir(file_path_pos)
print(lst_2)
new_file = open("valid_data.txt", "w+")

for file_name in lst:
    read_file = open(file_path + "/" + file_name, "r+")
    new_file.write(file_name[-5] + " ")
    content = read_file.read(1600)
    new_file.write(content)
    new_file.write("\n")
    read_file.close()

for file_name in lst_2:
    read_file = open(file_path_pos + "/" + file_name, "r+")
    new_file.write(file_name[-5] + " ")
    content = read_file.read(1600)
    new_file.write(content)
    new_file.write("\n")
    read_file.close()

new_file.close()

file_path = "/Users/wangzeyang/Desktop/CSC413/A2/aclImdb/train/neg"
file_path_pos = "/Users/wangzeyang/Desktop/CSC413/A2/aclImdb/train/pos"

lst = os.listdir(file_path)
lst_2 = os.listdir(file_path_pos)
print(lst_2)
new_file = open("train_data.txt", "w+")

for file_name in lst:
    read_file = open(file_path + "/" + file_name, "r+")
    new_file.write(file_name[-5] + " ")
    content = read_file.read(1600)
    new_file.write(content)
    new_file.write("\n")
    read_file.close()

for file_name in lst_2:
    read_file = open(file_path_pos + "/" + file_name, "r+")
    new_file.write(file_name[-5] + " ")
    content = read_file.read(1600)
    new_file.write(content)
    new_file.write("\n")
    read_file.close()

new_file.close()

# %% [markdown]
# Read data to colab

# %%
# upload dataset
from google.colab import drive
drive.mount('/content/gdrive')

# %%
train_path = '/content/gdrive/My Drive/CSC413/train_data.txt'
valid_path = '/content/gdrive/My Drive/CSC413/valid_data.txt'

# %% [markdown]
# # Part 1 Data anlyze

# %% [markdown]
# 1-a: Functions for data analyze.

# %%
import string
import collections

def get_score(path):
    data = []

    for line in open(path):
        score = int(line.replace("<br />", "").split()[0])
        data.append(score or 10)

    return data

def read_sentences1(path, max_word):
    data = []
    punct = string.punctuation

    for line in open(path):
        # replace <br/> and punctuations
        line_1 = line.replace("<br />", "")
        # remove punctuations
        for i in line_1:
            if i in punct:
                line_1 = line_1.replace(i, " ")
        words_1 = line_1.split()
        words = [word for word in words_1 if len(word) > 3]

        # set maximum length for each sentence and pad with <EOS>
        if len(words) > max_word:
            sentence = [word.lower() for word in words[0 : max_word]]
        else:
            sentence = [word.lower() for word in words[0:]]
        data.append(sentence)

    return data

def read_sentences2(path, max_word):
    data = []
    punct = string.punctuation
    stopWords = stopwords.words("english")
    stemmer = PorterStemmer()

    for line in open(path):
        # replace <br/> and punctuations
        line_1 = line.replace("<br />", "")
        # remove punctuations
        for i in line_1:
            if i in punct:
                line_1 = line_1.replace(i, " ")
        words_1 = line_1.split()
        # remove stop words
        words = [word for word in words_1 if len(word) > 3 and word not in stopWords]
        for i in range(len(words)):
            words[i] = stemmer.stem(words[i])
        for word in words:
            for l in range(len(word) - 2):
                if word[l] == word[l + 1] == word[l + 2]:
                    words.remove(word)
                    break
        for word in words:
            for l in word:
                if l.isdigit():
                    words.remove(word)
                    break

        if len(words) > max_word:
            sentence = [word.lower() for word in words[0 : max_word]]
        else:
            sentence = [word.lower() for word in words[0:]]
        data.append(sentence)

    return data

def word_anaylze(data):
    all_words = [word for sentence in data for word in sentence]

    word_counts = collections.Counter(all_words)

    print('Most common 10 words:')
    print(word_counts.most_common(10))
    vocabulary_size = len(word_counts)
    print("size of vocab：", vocabulary_size)

    sentence_lengths = [len(sentence) for sentence in data]
    sentence_length_counts = collections.Counter(sentence_lengths)
    print("sentence length：", sentence_length_counts)
    return

# %% [markdown]
# 1-b. Analyze the score part

# %%
import statistics
score_data = get_score(train_path)



print("total number of scores:", len(score_data))

occur_counts = []
for i in set(score_data):
    occur_counts.append(count:= score_data.count(i))
    print(i, "occurrence count: ", count)

print("negative sum: ", sum(occur_counts[:4]))
print("positive sum: ", sum(occur_counts[4:]))
print("mean：", statistics.mean(score_data))
print("median：", statistics.median(score_data))
print("most occurrence number：", statistics.mode(score_data))

# %% [markdown]
# 1-c. Analyze the word part

# %%
max_word = 100
words_data = read_sentences1(train_path, max_word)
words_data2 = read_sentences2(train_path, max_word)

# %%
print('before remove stop words: ')
word_anaylze(words_data)
print('after remove stop words: ')
word_anaylze(words_data2)

# %% [markdown]
# # Part 2 Data processing

# %%
import string

def read_sentences(path, max_word):
    data = []
    punct = string.punctuation
    stopWords = stopwords.words("english")
    stemmer = PorterStemmer()

    for line in open(path):
        # replace <br/> and punctuations
        line_1 = line.replace("<br />", "")
        # remove punctuations
        for i in line_1:
            if i in punct:
                line_1 = line_1.replace(i, " ")
        words_1 = line_1.split()
        # remove stop words
        words = [word for word in words_1 if len(word) > 4 and word not in stopWords]
        # reduce to root
        for i in range(len(words)):
            words[i] = stemmer.stem(words[i])
        # remove incorrect spelling words (words with 3 same letters)
        for word in words:
            for l in range(len(word) - 2):
                if word[l] == word[l + 1] == word[l + 2]:
                    words.remove(word)
                    break
        # remove digits
        for word in words:
            for l in word:
                if l.isdigit():
                    words.remove(word)
                    break

        # set maximum length for each sentence and pad with empty string
        if len(words) > max_word:
            sentence = [words_1[0], [word.lower() for word in words[0 : max_word]]]
        else:
            sent = [word.lower() for word in words[0:]]
            for i in range(len(words), max_word):
                sent.append("")
            sentence = [words_1[0], sent]
        data.append(sentence)

    return data


# read sentences and vocab
max_word = 100 
train_data_1 = np.array(read_sentences(train_path, max_word))
valid_data_1 = np.array(read_sentences(valid_path, max_word))


print(len(train_data_1))

vocab = set([w for s in train_data_1 for w in s[1]])

vocab_size = len(vocab)

print(vocab_size) # 41456

# %%
# split validation and test set 50%
splt_1 = 0
splt_2 = 12500
np.random.shuffle(valid_data_1)
np.random.shuffle(train_data_1)


train_data = np.concatenate((train_data_1, valid_data_1[0:splt_1]), axis=0)
valid_data = valid_data_1[splt_1:splt_1 + splt_2]
test_data = valid_data_1[splt_1 + splt_2:]

print(len(train_data)) # 30000
print(len(valid_data)) # 10000
print(len(test_data))  # 10000

# %%
# test if same number of positive and negative reviews in validation set
total_1 = 0
total_2 = 0
for i in valid_data:
    if int(i[0]) > 5 or int(i[0]) == 0:
        total_1 += 1
    else:
        total_2 += 1

print (total_1)
print (total_2)

# %% [markdown]
# **Input process**

# %%
vocab_lst = sorted(list(vocab))
# move padding char '' (empty string) to index 0
vocab_lst.remove("")
vocab_lst.insert(0, "")
print(len(vocab_lst), vocab_lst)
# A mapping of index => word (string)
vocab_itos = dict(enumerate(vocab_lst))
# A mapping of word => its index
vocab_stoi = {word:index for index, word in vocab_itos.items()}

def convert_words_to_indices(sents):
    indices = []
    for i in range(len(sents)):
      ind = []
      for word in sents[i]:
        ind.append(vocab_stoi[word] if word in vocab_lst else vocab_stoi[""])
      indices.append(ind)
    return indices

def get_batch(data, range_min, range_max):
    """
    Convert one batch of data in the form of sentence into input and output
    data and return the training data (xs, ts) where:
     - `xs` is an numpy array of indices [batch_size, max_word]
     - `ts` is a numpy array of shape [batch_size] containing indicies

    Preconditions:
     - `data` is a numpy array of shape [N, 2] 
     - range_max > range_min
    """
    xs, ts = [], []
    for d in data[range_min:range_max]:
        ts.append(int(d[0]))
        xs.append(d[1])
    xs = convert_words_to_indices(xs)
    xs = np.array(xs)
    ts = np.array(ts)
    
    return xs, ts

# %% [markdown]
# #Part 3 Build model and train

# %%
## model

class LSTMmodel(nn.Module):
    def __init__(self, vocab_size = vocab_size, emb_size = 100, num_hidden = 150):
        super(LSTMmodel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, emb_size)
        self.conv1 = nn.Conv1d(in_channels=emb_size, out_channels=32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2)
        self.lstm = nn.LSTM(50, num_hidden, batch_first=True)
        self.dropout = nn.Dropout(p=0.2)
        self.fc1 = nn.Linear(num_hidden, 50)
        self.fc2 = nn.Linear(50, 10)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = x.long() # for embedding type debug
        x = self.embedding(x)
        x = self.dropout(x)
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.lstm(x)[0]
        x = x[:, -1, :]
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.softmax(x)
        return x

# %% [markdown]
# **Train function**

# %%
def train(model, train_data = train_data, valid_data = valid_data, batch_size=32, weight_decay=0.0,
          learning_rate=0.001, max_iters=7, checkpoint_path=None):
  
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(), lr=learning_rate, 
                         weight_decay=weight_decay)

  iters, losses = [], []
  iters_sub, train_accs, val_accs  = [], [], []

  n = 0 # the number of iterations
  while True:
      for i in range(0, train_data.shape[0], batch_size):
          if (i + batch_size) > train_data.shape[0]:
              break

          # get the input and targets of a minibatch
          xs, ts = get_batch(train_data, i, i + batch_size)

          # convert from numpy arrays to PyTorch tensors
          xs = torch.Tensor(xs)
          ts = torch.Tensor(ts).long()

          zs = model(xs)
          loss = criterion(zs, ts) # compute the total loss
          loss.backward()          # compute updates for each parameter
          optimizer.step()         # make the updates for each parameter
          optimizer.zero_grad()    # a clean up step for PyTorch

          # save the current training information
          iters.append(n)
          losses.append(float(loss)/batch_size)  # compute *average* loss

          if n % 200 == 0: # was 500
              iters_sub.append(n)
              train_cost = float(loss.detach().numpy())
              train_acc = get_accuracy(model, train_data)
              train_accs.append(train_acc)
              val_acc = get_accuracy(model, valid_data)
              val_accs.append(val_acc)
              print("Iter %d. [Val Acc %.0f%%] [Train Acc %.0f%%, Loss %f]" % (
                    n, val_acc * 100, train_acc * 100, train_cost))

              if (checkpoint_path is not None) and n > 0:
                  torch.save(model.state_dict(), checkpoint_path.format(n))

          # increment the iteration number
          n += 1

          if n > max_iters:
              return iters, losses, iters_sub, train_accs, val_accs

# %% [markdown]
# **Accuracy**

# %%
def get_accuracy(model, data, batch_size=32, max_N=100):
    """
    Estimate the accuracy of the model on the data. To reduce
    computation time, use at most `max_N` elements of `data` to
    produce the estimate.
    """
    correct = 0
    correct_1 = 0
    N = 0
    for i in range(0, data.shape[0], batch_size):
        # get a batch of data
        xs, ts = get_batch(data, i, i + batch_size)
        
        # forward pass prediction
        z = model(torch.Tensor(xs))
        z = z.detach().numpy() # convert the PyTorch tensor => numpy array
        pred = np.argmax(z, axis=1)
        correct += np.sum(pred == ts)

        for i in range(1, 5):
            for j in range(1, 5):
                pred_cur = pred[pred == i]
                ts_cur = ts[pred == i]
                pred_cur = pred_cur[ts_cur == j]
                correct_1 += pred_cur.shape[0]

        for j in range(6, 10):
            for i in range(6, 10):
                pred_cur = pred[pred == i]
                ts_cur = ts[pred == i]
                pred_cur = pred_cur[ts_cur == j]
                correct_1 += pred_cur.shape[0]

                pred_cur = pred[pred == i]
                ts_cur = ts[pred == i]
                pred_cur = pred_cur[ts_cur == 0]
                correct_1 += pred_cur.shape[0]

            pred_cur = pred[pred == 0]
            ts_cur = ts[pred == 0]
            pred_cur = pred_cur[ts_cur == j]
            correct_1 += pred_cur.shape[0]

        N += ts.shape[0]

        if N > max_N:
            break
    acc_1 = correct / N
    acc_2 = correct_1 / N
    return acc_2

# %%
def get_accuracy_1(model, data, batch_size=32, max_N=100):
    """
    Estimate the accuracy of the model on the data. To reduce
    computation time, use at most `max_N` elements of `data` to
    produce the estimate.
    """
    correct = 0
    correct_1 = 0
    N = 0
    pred_list = []
    for i in range(0, data.shape[0], batch_size):
        # get a batch of data
        xs, ts = get_batch(data, i, i + batch_size)
        
        # forward pass prediction
        z = model(torch.Tensor(xs))

        z = z.detach().numpy() # convert the PyTorch tensor => numpy array
    
        pred = np.argmax(z, axis=1)
        pred_list.append(pred)

    return np.array(pred_list)

# %%
def plot_learning_curve(iters, losses, iters_sub, train_accs, val_accs):
    """
    Plot the learning curve.
    """
    plt.title("Learning Curve: Loss per Iteration")
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Learning Curve: Accuracy per Iteration")
    plt.plot(iters_sub, train_accs, label="Train")
    plt.plot(iters_sub, val_accs, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# **Naive-bayes model**

# %%
def read_sentences_naive(path, max_word):
    data = []
    punct = string.punctuation
    stopWords = stopwords.words("english")
    stemmer = PorterStemmer()

    for line in open(path):
        # replace <br/> and punctuations
        line_1 = line.replace("<br />", "")
        # remove punctuations
        for i in line_1:
            if i in punct:
                line_1 = line_1.replace(i, " ")
        words_1 = line_1.split()
        # remove stop words
        words = [word for word in words_1 if len(word) > 4 and word not in stopWords]
        for i in range(len(words)):
            words[i] = stemmer.stem(words[i])
        for word in words:
            for l in range(len(word) - 2):
                if word[l] == word[l + 1] == word[l + 2]:
                    words.remove(word)
                    break
        for word in words:
            for l in word:
                if l.isdigit():
                    words.remove(word)
                    break

        sentence = [int(words_1[0]), [word.lower() for word in words[0 : max_word]]]
        data.append(sentence)

    return data


# read sentences and vocab
max_word = 150 
train_data_naive = np.array(read_sentences_naive(train_path, max_word))
valid_naive = np.array(read_sentences_naive(valid_path, max_word))

vocab = set([w for s in train_data_naive for w in s[1]])
vocab_size = len(vocab)
print(vocab_size)

# %%
# split valid data set into valid set and test set
splt = len(valid_naive) // 2
test_data_naive = valid_naive[splt :]
valid_data_naive = valid_naive[: splt]

print(len(train_data_naive)) # 25000
print(len(valid_data_naive)) # 12500

# %%
print(train_data[0])

# %%
# Build the input of Naive-bayes model
train_sen = train_data_naive[:,1].tolist()
# print(train_sen[100])
t = train_data_naive[:,0]
t_list = t.tolist()
print(t_list)
t1 = np.zeros([len(t_list), 10])
for i in range(len(t_list)):
    t1[i][t_list[i]] = 1
print(t1)

# %%
print(len(train_sen))

# %%
# Build naive-bayes model
def make_matrix(data, vocab):
    num = 0
    true_vocab = {}
    for i in range(len(vocab)):
        true_vocab[vocab[i]] = i
    
    X = np.zeros([len(data), len(vocab)])
    for i in range(len(data)):
        list_vocab = data[i]
        
        for j in list_vocab:
            if j in vocab:
                X[i][true_vocab[j]] = 1
        num += 1
        print(num)

    return X

def naive_bayes_map(X, t, t1):
    N, vocab_size = X.shape[0], X.shape[1]
    t1_sum = t1.sum(0)
    pi = (t1_sum + 2 - 1) / (N + 2 + 2 - 2)
    theta = np.zeros([vocab_size, 10])

    X_1 = X[t == 1]
    X_2 = X[t == 2]
    X_3 = X[t == 3]
    X_4 = X[t == 4]
    X_5 = X[t == 5]
    X_6 = X[t == 6]
    X_7 = X[t == 7]
    X_8 = X[t == 8]
    X_9 = X[t == 9]
    X_10 = X[t == 0]
	
    N_1 = X_1.shape[0]
    X_1 = (X_1.sum(axis = 0) + 1) / (N_1 + 2)
    theta[:,0] = theta[:,0] + X_1

    N_2 = X_2.shape[0]
    X_2 = (X_2.sum(axis = 0) + 1) / (N_2 + 2)
    theta[:,1] = theta[:,1] + X_2

    N_3 = X_3.shape[0]
    X_3 = (X_3.sum(axis = 0) + 1) / (N_3 + 2)
    theta[:,2] = theta[:,2] + X_3

    N_4 = X_4.shape[0]
    X_4 = (X_4.sum(axis = 0) + 1) / (N_4 + 2)
    theta[:,3] = theta[:,3] + X_4

    N_5 = X_5.shape[0]
    X_5 = (X_5.sum(axis = 0) + 1) / (N_5 + 2)
    theta[:,4] = theta[:,4] + X_5

    N_6 = X_6.shape[0]
    X_6 = (X_6.sum(axis = 0) + 1) / (N_6 + 2)
    theta[:,5] = theta[:,5] + X_6

    N_7 = X_7.shape[0]
    X_7 = (X_7.sum(axis = 0) + 1) / (N_7 + 2)
    theta[:,6] = theta[:,6] + X_7

    N_8 = X_8.shape[0]
    X_8 = (X_8.sum(axis = 0) + 1) / (N_8 + 2)
    theta[:,7] = theta[:,7] + X_8

    N_9 = X_9.shape[0]
    X_9 = (X_9.sum(axis = 0) + 1) / (N_9 + 2)
    theta[:,8] = theta[:,8] + X_9

    N_10 = X_10.shape[0]
    X_10 = (X_10.sum(axis = 0) + 1) / (N_10 + 2)
    theta[:,9] = theta[:,9] + X_10

    return pi, theta

def training_3(data, t, t1, vocab):
    X = make_matrix(data, vocab)
    
    pi, theta = naive_bayes_map(X, t, t1)
    return [pi, theta, vocab]

# %%
# Create prediction function
def make_prediction_3(review, vocab, pi, theta):
    punctuation = string.punctuation
    for punc in punctuation:
        review = review.replace(punc, "")
    X = np.zeros([1, len(vocab)])
    words = review.split()
    for j, w in enumerate(vocab):
        if w in words:
            X[0, j] = 1

    V, K = theta.shape

    X_opposite = np.ones([1, V]) - X
    theta_opposite = np.ones([V, K]) - theta

    cur_largest_pro = 0
    cur_large_k = 0
    for k in range(K):
        exist = X * theta[:,k]
        not_exist = X_opposite * theta_opposite[:,k]
        All = exist + not_exist
        cur_p = np.log(All)
        cur_p = cur_p.sum(1)
        cur_p = np.exp(cur_p)
        cur_p = cur_p * pi[k]
        if cur_p > cur_largest_pro:
            cur_largest_pro = cur_p
            cur_large_k = k

    return cur_large_k + 1

# %%
# get accuracy
def get_accuracy_naive(data_set, vocab, pi, theta):
    accurate = 0
    acc = 0
    for i in data_set:
        sentence = i[1]
        cur_sen = ""
        for word in sentence:
            cur_sen += word + " "
        pred = make_prediction_3(cur_sen, vocab, pi, theta)
        if pred == i[0]:
            accurate += 1
        if 0 < pred < 6 and 0 < i[0] < 6:
            acc += 1
        if 5 < pred < 11 and 5 < i[0] < 11:
            acc += 1

    return acc / len(data_set)

# %%
def total_training_model(x, t, t1):
    model_total = []

    #training mode 1 -- RNN model

    model_1 = []

    lstm_model = LSTMmodel()
    learning_curve_info = train(lstm_model, max_iters=400)
    model_1.append(lstm_model)

    #training mode 2 -- Naive Bayes model

    model_3 = training_3(train_sen, t, t1, list(vocab))

    model_total.append(model_1)
    model_total.append(model_3)
    
    return model_total

# %%
def total_predict_1(x, test, test_data, vocab, model_total):
    cur_sen = ""
    for word in test:
        cur_sen += word + " "
    y2 = make_prediction_3(cur_sen, list(vocab), model_total[1][0], model_total[1][1])
    
    return y2
    
    
def total_predict_2(x, test_data, vocab, model_total):
    
    y1 = get_accuracy_1(model_total[0][0], test_data)

    return y1

# %%
model_total = total_training_model(train_data, t, t1)

# %% [markdown]
# # Part 4 Results

# %%
result_list = []
target_list = []
num_here = -1
for i in test_data:
    num_here += 1
    result = total_predict_1(train_data, i[1], valid_data, vocab, model_total)
    target = i[0]
    result_list.append(result)
    target_list.append(target)
    print ("number:", num_here, "result:", result, "target:", target)

result_1 = np.array(result_list)
target_1 = np.array(target_list)
print (test_data[1])

# %%
result_2 = total_predict_2(train_data, valid_data, vocab, model_total)

print(result_2)

# %%
result_3 = np.array([])

for i in result_2:
    result_3 = np.concatenate((result_3, i), axis = 0)

print(result_3.shape)
print(target_1.shape)
# Out:
# (12500,)
# (12500,)

# %%
result_input = np.vstack((result_1, result_3))
result_input = result_input.transpose()
print(result_input.shape)
# Out:
# (12500, 2)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression(fit_intercept=False).fit(result_input, target_1)
print(lr.coef_)
# Out:
# [0.76630422 1.5897359 ]

# %%
def final_total_predict_1(x, test, test_data, vocab, model_total):
    cur_sen = ""
    for word in test:
        cur_sen += word + " "
    y2 = make_prediction_3(cur_sen, list(vocab), model_total[1][0], model_total[1][1])
    
    return y2
    
    
def final_total_predict_2(x, test_data, vocab, model_total):
    
    y1 = get_accuracy_1(model_total[0][0], test_data)

    return y1

# %%
final_2 = final_total_predict_2(train_data, test_data, vocab, model_total)

final_3 = np.array([])

for i in final_2:
    final_3 = np.concatenate((final_3, i), axis = 0)

print(final_3.shape)
print(final_3)
# Out:
# (12500,)
# [0. 0. 1. ... 0. 1. 0.]
# <ipython-input-78-8b51ec17a987>:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(pred_list)

# %%
correct = 0
total = len(test_data)

for i in range(len(test_data)):
    result = total_predict_1(train_data, test_data[i][1], test_data, vocab, model_total)
    target = test_data[i][0]
    if int(target) == 0:
        target = 10
    else:
        target = int(target)
    
    result = int(result)

    result = (lr.coef_[1] * result + lr.coef_[0] * final_3[i]) / 2
    result = int(result)

    if int(target) < 5 and int(result) < 5:
        correct += 1

    if int(target) > 5 and int(result) > 5:
        correct += 1
    
    if i % 100 == 0 and i != 0:
        print(correct/i)
    
    print ("number:", i, "result:", result, "target:", target)

print(correct/total)
# Out:
# Streaming output truncated to the last 5000 lines.
# number: 7550 result: 1 target: 1
# number: 7551 result: 8 target: 9
# number: 7552 result: 6 target: 8
# number: 7553 result: 8 target: 10
# number: 7554 result: 1 target: 1
# number: 7555 result: 0 target: 1
# number: 7556 result: 1 target: 1
# number: 7557 result: 8 target: 9
# number: 7558 result: 3 target: 3
# number: 7559 result: 1 target: 9
# number: 7560 result: 0 target: 9
# number: 7561 result: 1 target: 3
# number: 7562 result: 8 target: 10
# number: 7563 result: 8 target: 8
# number: 7564 result: 7 target: 10
# number: 7565 result: 7 target: 10
# number: 7566 result: 1 target: 4
# number: 7567 result: 8 target: 10
# number: 7568 result: 1 target: 4
# number: 7569 result: 1 target: 2
# number: 7570 result: 1 target: 1
# number: 7571 result: 2 target: 3
# number: 7572 result: 1 target: 1
# number: 7573 result: 1 target: 4
# number: 7574 result: 1 target: 1
# number: 7575 result: 0 target: 10
# number: 7576 result: 1 target: 1
# number: 7577 result: 3 target: 4
# number: 7578 result: 1 target: 4
# number: 7579 result: 6 target: 7
# number: 7580 result: 3 target: 4
# number: 7581 result: 1 target: 4
# number: 7582 result: 7 target: 7
# number: 7583 result: 1 target: 2
# number: 7584 result: 0 target: 4
# number: 7585 result: 6 target: 8
# number: 7586 result: 8 target: 8
# number: 7587 result: 2 target: 4
# number: 7588 result: 0 target: 10
# number: 7589 result: 8 target: 9
# number: 7590 result: 6 target: 3
# number: 7591 result: 7 target: 3
# number: 7592 result: 6 target: 10
# number: 7593 result: 1 target: 2
# number: 7594 result: 7 target: 1
# number: 7595 result: 1 target: 7
# number: 7596 result: 1 target: 7
# number: 7597 result: 7 target: 7
# number: 7598 result: 0 target: 8
# number: 7599 result: 8 target: 4
# 0.8243421052631579
# number: 7600 result: 6 target: 8
# number: 7601 result: 8 target: 8
# number: 7602 result: 8 target: 8
# number: 7603 result: 8 target: 7
# number: 7604 result: 0 target: 4
# number: 7605 result: 1 target: 1
# number: 7606 result: 6 target: 7
# number: 7607 result: 0 target: 1
# number: 7608 result: 1 target: 1
# number: 7609 result: 6 target: 7
# number: 7610 result: 1 target: 3
# number: 7611 result: 8 target: 8
# number: 7612 result: 7 target: 10
# number: 7613 result: 8 target: 4
# number: 7614 result: 6 target: 7
# number: 7615 result: 1 target: 2
# number: 7616 result: 1 target: 10
# number: 7617 result: 6 target: 8
# number: 7618 result: 1 target: 8
# number: 7619 result: 1 target: 3
# number: 7620 result: 8 target: 8
# number: 7621 result: 6 target: 4
# number: 7622 result: 8 target: 10
# number: 7623 result: 7 target: 3
# number: 7624 result: 0 target: 2
# number: 7625 result: 1 target: 2
# number: 7626 result: 6 target: 8
# number: 7627 result: 0 target: 1
# number: 7628 result: 2 target: 4
# number: 7629 result: 8 target: 10
# number: 7630 result: 1 target: 2
# number: 7631 result: 8 target: 8
# number: 7632 result: 8 target: 10
# number: 7633 result: 1 target: 1
# number: 7634 result: 0 target: 8
# number: 7635 result: 1 target: 1
# number: 7636 result: 7 target: 10
# number: 7637 result: 6 target: 7
# number: 7638 result: 6 target: 3
# number: 7639 result: 1 target: 2
# number: 7640 result: 8 target: 10
# number: 7641 result: 2 target: 8
# number: 7642 result: 8 target: 7
# number: 7643 result: 3 target: 2
# number: 7644 result: 8 target: 10
# number: 7645 result: 1 target: 8
# number: 7646 result: 7 target: 8
# number: 7647 result: 1 target: 2
# number: 7648 result: 7 target: 8
# number: 7649 result: 1 target: 1
# number: 7650 result: 7 target: 9
# number: 7651 result: 1 target: 10
# number: 7652 result: 7 target: 10
# number: 7653 result: 8 target: 10
# number: 7654 result: 3 target: 2
# number: 7655 result: 7 target: 10
# number: 7656 result: 0 target: 2
# number: 7657 result: 7 target: 4
# number: 7658 result: 6 target: 7
# number: 7659 result: 1 target: 1
# number: 7660 result: 8 target: 10
# number: 7661 result: 7 target: 10
# number: 7662 result: 1 target: 1
# number: 7663 result: 8 target: 10
# number: 7664 result: 1 target: 3
# number: 7665 result: 1 target: 8
# number: 7666 result: 1 target: 1
# number: 7667 result: 7 target: 1
# number: 7668 result: 1 target: 1
# number: 7669 result: 1 target: 1
# number: 7670 result: 6 target: 9
# number: 7671 result: 8 target: 9
# number: 7672 result: 1 target: 1
# number: 7673 result: 1 target: 1
# number: 7674 result: 1 target: 8
# number: 7675 result: 8 target: 10
# number: 7676 result: 1 target: 7
# number: 7677 result: 7 target: 9
# number: 7678 result: 3 target: 4
# number: 7679 result: 1 target: 2
# number: 7680 result: 1 target: 10
# number: 7681 result: 1 target: 4
# number: 7682 result: 7 target: 10
# number: 7683 result: 1 target: 2
# number: 7684 result: 8 target: 8
# number: 7685 result: 7 target: 10
# number: 7686 result: 7 target: 10
# number: 7687 result: 1 target: 2
# number: 7688 result: 6 target: 3
# number: 7689 result: 8 target: 7
# number: 7690 result: 8 target: 10
# number: 7691 result: 1 target: 10
# number: 7692 result: 3 target: 2
# number: 7693 result: 7 target: 10
# number: 7694 result: 7 target: 9
# number: 7695 result: 8 target: 7
# number: 7696 result: 8 target: 9
# number: 7697 result: 3 target: 2
# number: 7698 result: 0 target: 8
# number: 7699 result: 1 target: 4
# 0.8241558441558442
# number: 7700 result: 8 target: 9
# number: 7701 result: 8 target: 8
# number: 7702 result: 1 target: 2
# number: 7703 result: 1 target: 2
# number: 7704 result: 3 target: 3
# number: 7705 result: 1 target: 2
# number: 7706 result: 7 target: 10
# number: 7707 result: 1 target: 3
# number: 7708 result: 1 target: 9
# number: 7709 result: 8 target: 7
# number: 7710 result: 1 target: 3
# number: 7711 result: 8 target: 9
# number: 7712 result: 2 target: 8
# number: 7713 result: 1 target: 1
# number: 7714 result: 8 target: 8
# number: 7715 result: 1 target: 3
# number: 7716 result: 0 target: 1
# number: 7717 result: 8 target: 10
# number: 7718 result: 1 target: 3
# number: 7719 result: 8 target: 10
# number: 7720 result: 8 target: 3
# number: 7721 result: 0 target: 9
# number: 7722 result: 8 target: 10
# number: 7723 result: 1 target: 4
# number: 7724 result: 3 target: 3
# number: 7725 result: 8 target: 10
# number: 7726 result: 1 target: 8
# number: 7727 result: 1 target: 8
# number: 7728 result: 1 target: 7
# number: 7729 result: 7 target: 9
# number: 7730 result: 7 target: 8
# number: 7731 result: 7 target: 10
# number: 7732 result: 6 target: 8
# number: 7733 result: 3 target: 4
# number: 7734 result: 8 target: 8
# number: 7735 result: 2 target: 7
# number: 7736 result: 8 target: 10
# number: 7737 result: 7 target: 8
# number: 7738 result: 8 target: 10
# number: 7739 result: 1 target: 8
# number: 7740 result: 1 target: 7
# number: 7741 result: 0 target: 7
# number: 7742 result: 0 target: 9
# number: 7743 result: 1 target: 8
# number: 7744 result: 1 target: 4
# number: 7745 result: 2 target: 1
# number: 7746 result: 2 target: 4
# number: 7747 result: 2 target: 2
# number: 7748 result: 1 target: 4
# number: 7749 result: 6 target: 2
# number: 7750 result: 8 target: 9
# number: 7751 result: 1 target: 8
# number: 7752 result: 6 target: 7
# number: 7753 result: 1 target: 3
# number: 7754 result: 1 target: 3
# number: 7755 result: 1 target: 1
# number: 7756 result: 1 target: 1
# number: 7757 result: 6 target: 7
# number: 7758 result: 8 target: 10
# number: 7759 result: 6 target: 7
# number: 7760 result: 8 target: 7
# number: 7761 result: 7 target: 10
# number: 7762 result: 6 target: 10
# number: 7763 result: 3 target: 3
# number: 7764 result: 0 target: 3
# number: 7765 result: 3 target: 4
# number: 7766 result: 3 target: 1
# number: 7767 result: 1 target: 1
# number: 7768 result: 6 target: 10
# number: 7769 result: 6 target: 8
# number: 7770 result: 1 target: 1
# number: 7771 result: 6 target: 8
# number: 7772 result: 6 target: 10
# number: 7773 result: 0 target: 1
# number: 7774 result: 8 target: 9
# number: 7775 result: 1 target: 1
# number: 7776 result: 3 target: 8
# number: 7777 result: 2 target: 2
# number: 7778 result: 3 target: 8
# number: 7779 result: 1 target: 1
# number: 7780 result: 1 target: 1
# number: 7781 result: 1 target: 2
# number: 7782 result: 1 target: 3
# number: 7783 result: 8 target: 10
# number: 7784 result: 1 target: 3
# number: 7785 result: 6 target: 10
# number: 7786 result: 7 target: 10
# number: 7787 result: 6 target: 10
# number: 7788 result: 3 target: 9
# number: 7789 result: 1 target: 3
# number: 7790 result: 6 target: 9
# number: 7791 result: 1 target: 1
# number: 7792 result: 7 target: 10
# number: 7793 result: 1 target: 3
# number: 7794 result: 8 target: 7
# number: 7795 result: 6 target: 8
# number: 7796 result: 3 target: 4
# number: 7797 result: 7 target: 10
# number: 7798 result: 7 target: 8
# number: 7799 result: 8 target: 9
# 0.823974358974359
# number: 7800 result: 1 target: 10
# number: 7801 result: 1 target: 1
# number: 7802 result: 3 target: 7
# number: 7803 result: 3 target: 4
# number: 7804 result: 8 target: 8
# number: 7805 result: 1 target: 1
# number: 7806 result: 0 target: 10
# number: 7807 result: 0 target: 1
# number: 7808 result: 8 target: 8
# number: 7809 result: 0 target: 3
# number: 7810 result: 1 target: 7
# number: 7811 result: 6 target: 8
# number: 7812 result: 8 target: 8
# number: 7813 result: 7 target: 10
# number: 7814 result: 6 target: 10
# number: 7815 result: 1 target: 2
# number: 7816 result: 1 target: 4
# number: 7817 result: 1 target: 2
# number: 7818 result: 1 target: 1
# number: 7819 result: 0 target: 1
# number: 7820 result: 1 target: 8
# number: 7821 result: 8 target: 10
# number: 7822 result: 6 target: 9
# number: 7823 result: 2 target: 7
# number: 7824 result: 1 target: 10
# number: 7825 result: 1 target: 1
# number: 7826 result: 0 target: 3
# number: 7827 result: 1 target: 8
# number: 7828 result: 8 target: 8
# number: 7829 result: 8 target: 10
# number: 7830 result: 8 target: 3
# number: 7831 result: 1 target: 7
# number: 7832 result: 2 target: 4
# number: 7833 result: 1 target: 2
# number: 7834 result: 8 target: 10
# number: 7835 result: 8 target: 10
# number: 7836 result: 3 target: 3
# number: 7837 result: 7 target: 9
# number: 7838 result: 8 target: 7
# number: 7839 result: 2 target: 1
# number: 7840 result: 7 target: 8
# number: 7841 result: 1 target: 4
# number: 7842 result: 1 target: 1
# number: 7843 result: 6 target: 1
# number: 7844 result: 6 target: 8
# number: 7845 result: 8 target: 10
# number: 7846 result: 6 target: 3
# number: 7847 result: 6 target: 8
# number: 7848 result: 1 target: 1
# number: 7849 result: 7 target: 2
# number: 7850 result: 3 target: 10
# number: 7851 result: 1 target: 1
# number: 7852 result: 8 target: 7
# number: 7853 result: 1 target: 4
# number: 7854 result: 8 target: 10
# number: 7855 result: 1 target: 3
# number: 7856 result: 7 target: 3
# number: 7857 result: 8 target: 9
# number: 7858 result: 6 target: 9
# number: 7859 result: 7 target: 10
# number: 7860 result: 8 target: 10
# number: 7861 result: 1 target: 1
# number: 7862 result: 0 target: 7
# number: 7863 result: 1 target: 4
# number: 7864 result: 6 target: 7
# number: 7865 result: 3 target: 2
# number: 7866 result: 0 target: 10
# number: 7867 result: 1 target: 1
# number: 7868 result: 7 target: 9
# number: 7869 result: 8 target: 8
# number: 7870 result: 6 target: 9
# number: 7871 result: 8 target: 8
# number: 7872 result: 7 target: 8
# number: 7873 result: 8 target: 4
# number: 7874 result: 1 target: 7
# number: 7875 result: 7 target: 10
# number: 7876 result: 1 target: 2
# number: 7877 result: 6 target: 7
# number: 7878 result: 7 target: 10
# number: 7879 result: 3 target: 9
# number: 7880 result: 8 target: 1
# number: 7881 result: 3 target: 1
# number: 7882 result: 1 target: 3
# number: 7883 result: 3 target: 7
# number: 7884 result: 7 target: 8
# number: 7885 result: 0 target: 2
# number: 7886 result: 6 target: 8
# number: 7887 result: 3 target: 3
# number: 7888 result: 0 target: 1
# number: 7889 result: 8 target: 10
# number: 7890 result: 7 target: 10
# number: 7891 result: 1 target: 3
# number: 7892 result: 3 target: 1
# number: 7893 result: 3 target: 3
# number: 7894 result: 8 target: 10
# number: 7895 result: 6 target: 7
# number: 7896 result: 6 target: 4
# number: 7897 result: 3 target: 4
# number: 7898 result: 7 target: 8
# number: 7899 result: 7 target: 8
# 0.8232911392405063
# number: 7900 result: 1 target: 9
# number: 7901 result: 8 target: 10
# number: 7902 result: 1 target: 1
# number: 7903 result: 1 target: 3
# number: 7904 result: 8 target: 7
# number: 7905 result: 8 target: 10
# number: 7906 result: 0 target: 1
# number: 7907 result: 1 target: 1
# number: 7908 result: 8 target: 7
# number: 7909 result: 2 target: 2
# number: 7910 result: 3 target: 4
# number: 7911 result: 1 target: 2
# number: 7912 result: 8 target: 10
# number: 7913 result: 2 target: 4
# number: 7914 result: 1 target: 1
# number: 7915 result: 6 target: 9
# number: 7916 result: 6 target: 10
# number: 7917 result: 1 target: 1
# number: 7918 result: 0 target: 8
# number: 7919 result: 8 target: 8
# number: 7920 result: 6 target: 9
# number: 7921 result: 1 target: 10
# number: 7922 result: 3 target: 3
# number: 7923 result: 7 target: 10
# number: 7924 result: 1 target: 3
# number: 7925 result: 1 target: 3
# number: 7926 result: 1 target: 10
# number: 7927 result: 1 target: 1
# number: 7928 result: 2 target: 3
# number: 7929 result: 1 target: 4
# number: 7930 result: 3 target: 2
# number: 7931 result: 8 target: 8
# number: 7932 result: 7 target: 10
# number: 7933 result: 8 target: 9
# number: 7934 result: 1 target: 1
# number: 7935 result: 7 target: 7
# number: 7936 result: 7 target: 7
# number: 7937 result: 8 target: 9
# number: 7938 result: 6 target: 8
# number: 7939 result: 1 target: 1
# number: 7940 result: 8 target: 10
# number: 7941 result: 8 target: 10
# number: 7942 result: 8 target: 9
# number: 7943 result: 8 target: 10
# number: 7944 result: 0 target: 1
# number: 7945 result: 0 target: 8
# number: 7946 result: 0 target: 1
# number: 7947 result: 7 target: 7
# number: 7948 result: 1 target: 3
# number: 7949 result: 1 target: 3
# number: 7950 result: 8 target: 7
# number: 7951 result: 8 target: 7
# number: 7952 result: 7 target: 10
# number: 7953 result: 7 target: 10
# number: 7954 result: 2 target: 7
# number: 7955 result: 1 target: 1
# number: 7956 result: 8 target: 10
# number: 7957 result: 7 target: 9
# number: 7958 result: 6 target: 10
# number: 7959 result: 3 target: 4
# number: 7960 result: 1 target: 3
# number: 7961 result: 8 target: 10
# number: 7962 result: 8 target: 8
# number: 7963 result: 7 target: 8
# number: 7964 result: 1 target: 3
# number: 7965 result: 0 target: 7
# number: 7966 result: 8 target: 8
# number: 7967 result: 0 target: 4
# number: 7968 result: 1 target: 7
# number: 7969 result: 1 target: 1
# number: 7970 result: 1 target: 4
# number: 7971 result: 3 target: 4
# number: 7972 result: 1 target: 2
# number: 7973 result: 8 target: 9
# number: 7974 result: 3 target: 4
# number: 7975 result: 0 target: 10
# number: 7976 result: 1 target: 1
# number: 7977 result: 8 target: 1
# number: 7978 result: 1 target: 7
# number: 7979 result: 0 target: 2
# number: 7980 result: 1 target: 10
# number: 7981 result: 1 target: 1
# number: 7982 result: 8 target: 10
# number: 7983 result: 0 target: 1
# number: 7984 result: 2 target: 8
# number: 7985 result: 1 target: 4
# number: 7986 result: 3 target: 3
# number: 7987 result: 8 target: 1
# number: 7988 result: 8 target: 10
# number: 7989 result: 3 target: 4
# number: 7990 result: 6 target: 8
# number: 7991 result: 8 target: 8
# number: 7992 result: 1 target: 10
# number: 7993 result: 6 target: 10
# number: 7994 result: 8 target: 4
# number: 7995 result: 1 target: 1
# number: 7996 result: 6 target: 8
# number: 7997 result: 8 target: 10
# number: 7998 result: 6 target: 10
# number: 7999 result: 6 target: 3
# 0.8235
# number: 8000 result: 0 target: 1
# number: 8001 result: 1 target: 4
# number: 8002 result: 8 target: 4
# number: 8003 result: 1 target: 2
# number: 8004 result: 1 target: 1
# number: 8005 result: 1 target: 1
# number: 8006 result: 3 target: 3
# number: 8007 result: 0 target: 1
# number: 8008 result: 8 target: 9
# number: 8009 result: 2 target: 10
# number: 8010 result: 6 target: 3
# number: 8011 result: 7 target: 7
# number: 8012 result: 6 target: 10
# number: 8013 result: 7 target: 9
# number: 8014 result: 6 target: 7
# number: 8015 result: 1 target: 3
# number: 8016 result: 1 target: 2
# number: 8017 result: 6 target: 8
# number: 8018 result: 3 target: 4
# number: 8019 result: 1 target: 10
# number: 8020 result: 8 target: 9
# number: 8021 result: 1 target: 4
# number: 8022 result: 6 target: 9
# number: 8023 result: 1 target: 1
# number: 8024 result: 7 target: 10
# number: 8025 result: 6 target: 10
# number: 8026 result: 1 target: 3
# number: 8027 result: 8 target: 7
# number: 8028 result: 1 target: 10
# number: 8029 result: 1 target: 4
# number: 8030 result: 8 target: 9
# number: 8031 result: 1 target: 2
# number: 8032 result: 1 target: 1
# number: 8033 result: 1 target: 2
# number: 8034 result: 1 target: 4
# number: 8035 result: 0 target: 1
# number: 8036 result: 0 target: 1
# number: 8037 result: 6 target: 8
# number: 8038 result: 8 target: 10
# number: 8039 result: 0 target: 1
# number: 8040 result: 3 target: 4
# number: 8041 result: 7 target: 10
# number: 8042 result: 8 target: 8
# number: 8043 result: 3 target: 9
# number: 8044 result: 8 target: 10
# number: 8045 result: 1 target: 1
# number: 8046 result: 8 target: 10
# number: 8047 result: 8 target: 7
# number: 8048 result: 7 target: 9
# number: 8049 result: 8 target: 3
# number: 8050 result: 1 target: 4
# number: 8051 result: 6 target: 9
# number: 8052 result: 3 target: 9
# number: 8053 result: 7 target: 1
# number: 8054 result: 1 target: 2
# number: 8055 result: 1 target: 4
# number: 8056 result: 1 target: 1
# number: 8057 result: 8 target: 9
# number: 8058 result: 1 target: 4
# number: 8059 result: 7 target: 10
# number: 8060 result: 8 target: 10
# number: 8061 result: 6 target: 7
# number: 8062 result: 1 target: 3
# number: 8063 result: 8 target: 10
# number: 8064 result: 1 target: 3
# number: 8065 result: 1 target: 4
# number: 8066 result: 6 target: 3
# number: 8067 result: 7 target: 2
# number: 8068 result: 8 target: 10
# number: 8069 result: 1 target: 1
# number: 8070 result: 8 target: 9
# number: 8071 result: 1 target: 1
# number: 8072 result: 7 target: 10
# number: 8073 result: 8 target: 7
# number: 8074 result: 1 target: 1
# number: 8075 result: 1 target: 3
# number: 8076 result: 1 target: 3
# number: 8077 result: 6 target: 9
# number: 8078 result: 2 target: 4
# number: 8079 result: 7 target: 1
# number: 8080 result: 8 target: 10
# number: 8081 result: 1 target: 1
# number: 8082 result: 0 target: 10
# number: 8083 result: 7 target: 10
# number: 8084 result: 1 target: 1
# number: 8085 result: 7 target: 10
# number: 8086 result: 7 target: 7
# number: 8087 result: 6 target: 10
# number: 8088 result: 1 target: 1
# number: 8089 result: 8 target: 2
# number: 8090 result: 1 target: 10
# number: 8091 result: 8 target: 10
# number: 8092 result: 8 target: 9
# number: 8093 result: 1 target: 3
# number: 8094 result: 1 target: 1
# number: 8095 result: 8 target: 10
# number: 8096 result: 7 target: 8
# number: 8097 result: 1 target: 3
# number: 8098 result: 1 target: 7
# number: 8099 result: 6 target: 9
# 0.8237037037037037
# number: 8100 result: 1 target: 4
# number: 8101 result: 8 target: 10
# number: 8102 result: 6 target: 9
# number: 8103 result: 8 target: 9
# number: 8104 result: 1 target: 2
# number: 8105 result: 8 target: 8
# number: 8106 result: 1 target: 1
# number: 8107 result: 3 target: 4
# number: 8108 result: 1 target: 1
# number: 8109 result: 1 target: 1
# number: 8110 result: 8 target: 10
# number: 8111 result: 1 target: 2
# number: 8112 result: 1 target: 1
# number: 8113 result: 0 target: 1
# number: 8114 result: 1 target: 3
# number: 8115 result: 3 target: 2
# number: 8116 result: 8 target: 8
# number: 8117 result: 8 target: 9
# number: 8118 result: 1 target: 1
# number: 8119 result: 8 target: 9
# number: 8120 result: 0 target: 1
# number: 8121 result: 1 target: 1
# number: 8122 result: 0 target: 2
# number: 8123 result: 7 target: 2
# number: 8124 result: 7 target: 10
# number: 8125 result: 8 target: 10
# number: 8126 result: 2 target: 3
# number: 8127 result: 1 target: 3
# number: 8128 result: 3 target: 7
# number: 8129 result: 6 target: 4
# number: 8130 result: 8 target: 7
# number: 8131 result: 3 target: 7
# number: 8132 result: 8 target: 7
# number: 8133 result: 7 target: 10
# number: 8134 result: 1 target: 4
# number: 8135 result: 8 target: 10
# number: 8136 result: 7 target: 7
# number: 8137 result: 1 target: 1
# number: 8138 result: 1 target: 3
# number: 8139 result: 8 target: 7
# number: 8140 result: 8 target: 10
# number: 8141 result: 8 target: 9
# number: 8142 result: 7 target: 8
# number: 8143 result: 6 target: 3
# number: 8144 result: 1 target: 1
# number: 8145 result: 3 target: 3
# number: 8146 result: 8 target: 8
# number: 8147 result: 1 target: 1
# number: 8148 result: 7 target: 7
# number: 8149 result: 7 target: 10
# number: 8150 result: 1 target: 1
# number: 8151 result: 1 target: 1
# number: 8152 result: 3 target: 1
# number: 8153 result: 8 target: 10
# number: 8154 result: 1 target: 2
# number: 8155 result: 8 target: 1
# number: 8156 result: 8 target: 10
# number: 8157 result: 6 target: 7
# number: 8158 result: 1 target: 1
# number: 8159 result: 7 target: 10
# number: 8160 result: 1 target: 3
# number: 8161 result: 3 target: 4
# number: 8162 result: 0 target: 2
# number: 8163 result: 0 target: 10
# number: 8164 result: 1 target: 9
# number: 8165 result: 1 target: 3
# number: 8166 result: 1 target: 2
# number: 8167 result: 1 target: 3
# number: 8168 result: 3 target: 7
# number: 8169 result: 0 target: 3
# number: 8170 result: 8 target: 3
# number: 8171 result: 0 target: 2
# number: 8172 result: 0 target: 2
# number: 8173 result: 1 target: 10
# number: 8174 result: 6 target: 7
# number: 8175 result: 7 target: 9
# number: 8176 result: 1 target: 3
# number: 8177 result: 1 target: 3
# number: 8178 result: 0 target: 10
# number: 8179 result: 6 target: 7
# number: 8180 result: 6 target: 7
# number: 8181 result: 0 target: 1
# number: 8182 result: 1 target: 1
# number: 8183 result: 6 target: 8
# number: 8184 result: 1 target: 10
# number: 8185 result: 1 target: 4
# number: 8186 result: 1 target: 3
# number: 8187 result: 8 target: 8
# number: 8188 result: 3 target: 4
# number: 8189 result: 0 target: 2
# number: 8190 result: 6 target: 8
# number: 8191 result: 8 target: 7
# number: 8192 result: 8 target: 10
# number: 8193 result: 7 target: 9
# number: 8194 result: 7 target: 1
# number: 8195 result: 7 target: 10
# number: 8196 result: 1 target: 7
# number: 8197 result: 6 target: 4
# number: 8198 result: 7 target: 10
# number: 8199 result: 1 target: 2
# 0.8239024390243902
# number: 8200 result: 1 target: 1
# number: 8201 result: 1 target: 1
# number: 8202 result: 7 target: 10
# number: 8203 result: 3 target: 4
# number: 8204 result: 7 target: 8
# number: 8205 result: 7 target: 7
# number: 8206 result: 6 target: 8
# number: 8207 result: 8 target: 8
# number: 8208 result: 1 target: 3
# number: 8209 result: 0 target: 1
# number: 8210 result: 1 target: 2
# number: 8211 result: 1 target: 2
# number: 8212 result: 1 target: 10
# number: 8213 result: 7 target: 10
# number: 8214 result: 3 target: 4
# number: 8215 result: 8 target: 2
# number: 8216 result: 1 target: 8
# number: 8217 result: 6 target: 4
# number: 8218 result: 8 target: 9
# number: 8219 result: 3 target: 10
# number: 8220 result: 1 target: 4
# number: 8221 result: 0 target: 4
# number: 8222 result: 1 target: 4
# number: 8223 result: 0 target: 9
# number: 8224 result: 7 target: 7
# number: 8225 result: 3 target: 2
# number: 8226 result: 1 target: 4
# number: 8227 result: 1 target: 1
# number: 8228 result: 1 target: 3
# number: 8229 result: 7 target: 10
# number: 8230 result: 1 target: 1
# number: 8231 result: 1 target: 4
# number: 8232 result: 7 target: 9
# number: 8233 result: 1 target: 3
# number: 8234 result: 1 target: 1
# number: 8235 result: 8 target: 9
# number: 8236 result: 2 target: 1
# number: 8237 result: 1 target: 1
# number: 8238 result: 7 target: 7
# number: 8239 result: 8 target: 7
# number: 8240 result: 1 target: 1
# number: 8241 result: 7 target: 7
# number: 8242 result: 1 target: 2
# number: 8243 result: 7 target: 9
# number: 8244 result: 1 target: 4
# number: 8245 result: 1 target: 1
# number: 8246 result: 0 target: 2
# number: 8247 result: 3 target: 10
# number: 8248 result: 0 target: 10
# number: 8249 result: 1 target: 1
# number: 8250 result: 8 target: 10
# number: 8251 result: 1 target: 1
# number: 8252 result: 0 target: 3
# number: 8253 result: 8 target: 8
# number: 8254 result: 8 target: 4
# number: 8255 result: 1 target: 1
# number: 8256 result: 0 target: 1
# number: 8257 result: 7 target: 8
# number: 8258 result: 1 target: 2
# number: 8259 result: 1 target: 10
# number: 8260 result: 0 target: 1
# number: 8261 result: 3 target: 4
# number: 8262 result: 8 target: 10
# number: 8263 result: 3 target: 1
# number: 8264 result: 7 target: 7
# number: 8265 result: 8 target: 3
# number: 8266 result: 1 target: 3
# number: 8267 result: 3 target: 4
# number: 8268 result: 1 target: 3
# number: 8269 result: 3 target: 3
# number: 8270 result: 3 target: 1
# number: 8271 result: 1 target: 2
# number: 8272 result: 1 target: 3
# number: 8273 result: 0 target: 2
# number: 8274 result: 8 target: 10
# number: 8275 result: 8 target: 9
# number: 8276 result: 7 target: 10
# number: 8277 result: 1 target: 4
# number: 8278 result: 0 target: 1
# number: 8279 result: 1 target: 10
# number: 8280 result: 1 target: 7
# number: 8281 result: 1 target: 1
# number: 8282 result: 8 target: 10
# number: 8283 result: 1 target: 4
# number: 8284 result: 7 target: 9
# number: 8285 result: 3 target: 2
# number: 8286 result: 0 target: 4
# number: 8287 result: 7 target: 10
# number: 8288 result: 8 target: 1
# number: 8289 result: 8 target: 10
# number: 8290 result: 1 target: 4
# number: 8291 result: 1 target: 4
# number: 8292 result: 8 target: 1
# number: 8293 result: 3 target: 4
# number: 8294 result: 6 target: 8
# number: 8295 result: 0 target: 7
# number: 8296 result: 8 target: 10
# number: 8297 result: 3 target: 4
# number: 8298 result: 0 target: 2
# number: 8299 result: 6 target: 8
# 0.8240963855421687
# number: 8300 result: 7 target: 9
# number: 8301 result: 1 target: 1
# number: 8302 result: 6 target: 7
# number: 8303 result: 1 target: 3
# number: 8304 result: 0 target: 1
# number: 8305 result: 6 target: 4
# number: 8306 result: 1 target: 4
# number: 8307 result: 8 target: 8
# number: 8308 result: 1 target: 4
# number: 8309 result: 1 target: 1
# number: 8310 result: 6 target: 10
# number: 8311 result: 6 target: 1
# number: 8312 result: 0 target: 7
# number: 8313 result: 8 target: 10
# number: 8314 result: 8 target: 10
# number: 8315 result: 8 target: 9
# number: 8316 result: 0 target: 10
# number: 8317 result: 8 target: 10
# number: 8318 result: 7 target: 10
# number: 8319 result: 7 target: 2
# number: 8320 result: 7 target: 10
# number: 8321 result: 7 target: 7
# number: 8322 result: 1 target: 2
# number: 8323 result: 7 target: 8
# number: 8324 result: 1 target: 1
# number: 8325 result: 0 target: 2
# number: 8326 result: 3 target: 4
# number: 8327 result: 8 target: 9
# number: 8328 result: 1 target: 1
# number: 8329 result: 1 target: 2
# number: 8330 result: 6 target: 10
# number: 8331 result: 2 target: 8
# number: 8332 result: 8 target: 4
# number: 8333 result: 1 target: 9
# number: 8334 result: 1 target: 9
# number: 8335 result: 1 target: 1
# number: 8336 result: 7 target: 10
# number: 8337 result: 1 target: 3
# number: 8338 result: 1 target: 1
# number: 8339 result: 7 target: 9
# number: 8340 result: 1 target: 3
# number: 8341 result: 1 target: 3
# number: 8342 result: 0 target: 1
# number: 8343 result: 1 target: 2
# number: 8344 result: 8 target: 8
# number: 8345 result: 1 target: 1
# number: 8346 result: 8 target: 8
# number: 8347 result: 1 target: 2
# number: 8348 result: 0 target: 1
# number: 8349 result: 1 target: 2
# number: 8350 result: 3 target: 4
# number: 8351 result: 0 target: 9
# number: 8352 result: 7 target: 10
# number: 8353 result: 7 target: 10
# number: 8354 result: 8 target: 10
# number: 8355 result: 1 target: 1
# number: 8356 result: 3 target: 7
# number: 8357 result: 0 target: 4
# number: 8358 result: 8 target: 8
# number: 8359 result: 0 target: 8
# number: 8360 result: 6 target: 8
# number: 8361 result: 1 target: 2
# number: 8362 result: 8 target: 7
# number: 8363 result: 7 target: 3
# number: 8364 result: 3 target: 4
# number: 8365 result: 8 target: 10
# number: 8366 result: 6 target: 9
# number: 8367 result: 8 target: 7
# number: 8368 result: 6 target: 7
# number: 8369 result: 1 target: 2
# number: 8370 result: 6 target: 4
# number: 8371 result: 1 target: 3
# number: 8372 result: 7 target: 9
# number: 8373 result: 7 target: 10
# number: 8374 result: 0 target: 1
# number: 8375 result: 2 target: 1
# number: 8376 result: 6 target: 4
# number: 8377 result: 8 target: 1
# number: 8378 result: 1 target: 2
# number: 8379 result: 7 target: 10
# number: 8380 result: 1 target: 8
# number: 8381 result: 8 target: 10
# number: 8382 result: 0 target: 7
# number: 8383 result: 1 target: 4
# number: 8384 result: 0 target: 2
# number: 8385 result: 1 target: 4
# number: 8386 result: 1 target: 8
# number: 8387 result: 8 target: 10
# number: 8388 result: 8 target: 10
# number: 8389 result: 7 target: 8
# number: 8390 result: 8 target: 10
# number: 8391 result: 1 target: 2
# number: 8392 result: 1 target: 2
# number: 8393 result: 3 target: 7
# number: 8394 result: 7 target: 10
# number: 8395 result: 1 target: 7
# number: 8396 result: 0 target: 1
# number: 8397 result: 8 target: 8
# number: 8398 result: 1 target: 2
# number: 8399 result: 2 target: 4
# 0.8235714285714286
# number: 8400 result: 8 target: 3
# number: 8401 result: 1 target: 1
# number: 8402 result: 8 target: 2
# number: 8403 result: 1 target: 4
# number: 8404 result: 8 target: 10
# number: 8405 result: 6 target: 3
# number: 8406 result: 8 target: 10
# number: 8407 result: 1 target: 1
# number: 8408 result: 7 target: 9
# number: 8409 result: 8 target: 8
# number: 8410 result: 3 target: 3
# number: 8411 result: 8 target: 9
# number: 8412 result: 7 target: 10
# number: 8413 result: 7 target: 10
# number: 8414 result: 8 target: 2
# number: 8415 result: 6 target: 9
# number: 8416 result: 8 target: 3
# number: 8417 result: 8 target: 10
# number: 8418 result: 1 target: 1
# number: 8419 result: 0 target: 2
# number: 8420 result: 1 target: 3
# number: 8421 result: 1 target: 1
# number: 8422 result: 8 target: 9
# number: 8423 result: 1 target: 4
# number: 8424 result: 7 target: 9
# number: 8425 result: 6 target: 8
# number: 8426 result: 1 target: 1
# number: 8427 result: 6 target: 10
# number: 8428 result: 7 target: 9
# number: 8429 result: 0 target: 10
# number: 8430 result: 1 target: 1
# number: 8431 result: 1 target: 1
# number: 8432 result: 6 target: 10
# number: 8433 result: 7 target: 8
# number: 8434 result: 1 target: 9
# number: 8435 result: 1 target: 1
# number: 8436 result: 8 target: 7
# number: 8437 result: 1 target: 1
# number: 8438 result: 7 target: 8
# number: 8439 result: 1 target: 2
# number: 8440 result: 8 target: 7
# number: 8441 result: 3 target: 4
# number: 8442 result: 1 target: 2
# number: 8443 result: 1 target: 1
# number: 8444 result: 8 target: 10
# number: 8445 result: 6 target: 4
# number: 8446 result: 0 target: 10
# number: 8447 result: 6 target: 7
# number: 8448 result: 0 target: 1
# number: 8449 result: 8 target: 8
# number: 8450 result: 1 target: 2
# number: 8451 result: 1 target: 7
# number: 8452 result: 1 target: 2
# number: 8453 result: 7 target: 10
# number: 8454 result: 5 target: 8
# number: 8455 result: 6 target: 1
# number: 8456 result: 8 target: 9
# number: 8457 result: 1 target: 10
# number: 8458 result: 3 target: 7
# number: 8459 result: 7 target: 7
# number: 8460 result: 1 target: 3
# number: 8461 result: 1 target: 7
# number: 8462 result: 8 target: 10
# number: 8463 result: 3 target: 3
# number: 8464 result: 3 target: 3
# number: 8465 result: 0 target: 1
# number: 8466 result: 7 target: 10
# number: 8467 result: 1 target: 1
# number: 8468 result: 0 target: 4
# number: 8469 result: 3 target: 4
# number: 8470 result: 1 target: 10
# number: 8471 result: 3 target: 3
# number: 8472 result: 8 target: 9
# number: 8473 result: 3 target: 1
# number: 8474 result: 0 target: 1
# number: 8475 result: 6 target: 9
# number: 8476 result: 8 target: 10
# number: 8477 result: 8 target: 10
# number: 8478 result: 7 target: 8
# number: 8479 result: 8 target: 8
# number: 8480 result: 1 target: 1
# number: 8481 result: 1 target: 3
# number: 8482 result: 8 target: 10
# number: 8483 result: 1 target: 3
# number: 8484 result: 8 target: 7
# number: 8485 result: 7 target: 10
# number: 8486 result: 1 target: 3
# number: 8487 result: 7 target: 8
# number: 8488 result: 7 target: 10
# number: 8489 result: 1 target: 2
# number: 8490 result: 7 target: 10
# number: 8491 result: 6 target: 8
# number: 8492 result: 6 target: 2
# number: 8493 result: 8 target: 10
# number: 8494 result: 1 target: 1
# number: 8495 result: 6 target: 4
# number: 8496 result: 0 target: 1
# number: 8497 result: 8 target: 10
# number: 8498 result: 7 target: 3
# number: 8499 result: 1 target: 3
# 0.8234117647058824
# number: 8500 result: 7 target: 3
# number: 8501 result: 1 target: 2
# number: 8502 result: 1 target: 10
# number: 8503 result: 1 target: 3
# number: 8504 result: 8 target: 7
# number: 8505 result: 3 target: 3
# number: 8506 result: 8 target: 7
# number: 8507 result: 1 target: 1
# number: 8508 result: 1 target: 2
# number: 8509 result: 6 target: 7
# number: 8510 result: 1 target: 3
# number: 8511 result: 1 target: 3
# number: 8512 result: 8 target: 4
# number: 8513 result: 1 target: 1
# number: 8514 result: 1 target: 4
# number: 8515 result: 0 target: 1
# number: 8516 result: 3 target: 3
# number: 8517 result: 1 target: 1
# number: 8518 result: 6 target: 10
# number: 8519 result: 8 target: 10
# number: 8520 result: 8 target: 10
# number: 8521 result: 7 target: 7
# number: 8522 result: 2 target: 1
# number: 8523 result: 0 target: 1
# number: 8524 result: 6 target: 8
# number: 8525 result: 7 target: 8
# number: 8526 result: 6 target: 7
# number: 8527 result: 7 target: 8
# number: 8528 result: 1 target: 2
# number: 8529 result: 8 target: 8
# number: 8530 result: 8 target: 10
# number: 8531 result: 3 target: 2
# number: 8532 result: 1 target: 1
# number: 8533 result: 8 target: 8
# number: 8534 result: 8 target: 9
# number: 8535 result: 7 target: 9
# number: 8536 result: 8 target: 8
# number: 8537 result: 6 target: 9
# number: 8538 result: 6 target: 10
# number: 8539 result: 0 target: 4
# number: 8540 result: 1 target: 1
# number: 8541 result: 6 target: 7
# number: 8542 result: 7 target: 10
# number: 8543 result: 7 target: 1
# number: 8544 result: 1 target: 2
# number: 8545 result: 8 target: 10
# number: 8546 result: 1 target: 9
# number: 8547 result: 7 target: 10
# number: 8548 result: 3 target: 7
# number: 8549 result: 8 target: 10
# number: 8550 result: 6 target: 10
# number: 8551 result: 1 target: 2
# number: 8552 result: 1 target: 2
# number: 8553 result: 8 target: 7
# number: 8554 result: 8 target: 8
# number: 8555 result: 7 target: 10
# number: 8556 result: 7 target: 10
# number: 8557 result: 0 target: 4
# number: 8558 result: 8 target: 10
# number: 8559 result: 3 target: 9
# number: 8560 result: 1 target: 1
# number: 8561 result: 0 target: 8
# number: 8562 result: 8 target: 8
# number: 8563 result: 3 target: 7
# number: 8564 result: 8 target: 10
# number: 8565 result: 1 target: 1
# number: 8566 result: 8 target: 10
# number: 8567 result: 1 target: 3
# number: 8568 result: 8 target: 4
# number: 8569 result: 6 target: 4
# number: 8570 result: 1 target: 1
# number: 8571 result: 1 target: 3
# number: 8572 result: 0 target: 1
# number: 8573 result: 1 target: 10
# number: 8574 result: 3 target: 3
# number: 8575 result: 7 target: 10
# number: 8576 result: 6 target: 10
# number: 8577 result: 7 target: 10
# number: 8578 result: 1 target: 1
# number: 8579 result: 7 target: 9
# number: 8580 result: 1 target: 1
# number: 8581 result: 8 target: 9
# number: 8582 result: 1 target: 8
# number: 8583 result: 1 target: 2
# number: 8584 result: 6 target: 10
# number: 8585 result: 8 target: 10
# number: 8586 result: 2 target: 1
# number: 8587 result: 6 target: 1
# number: 8588 result: 7 target: 9
# number: 8589 result: 8 target: 10
# number: 8590 result: 7 target: 10
# number: 8591 result: 8 target: 8
# number: 8592 result: 1 target: 1
# number: 8593 result: 7 target: 10
# number: 8594 result: 7 target: 10
# number: 8595 result: 1 target: 1
# number: 8596 result: 6 target: 10
# number: 8597 result: 6 target: 2
# number: 8598 result: 6 target: 3
# number: 8599 result: 6 target: 7
# 0.8237209302325581
# number: 8600 result: 3 target: 4
# number: 8601 result: 0 target: 4
# number: 8602 result: 0 target: 10
# number: 8603 result: 1 target: 1
# number: 8604 result: 8 target: 10
# number: 8605 result: 8 target: 9
# number: 8606 result: 1 target: 3
# number: 8607 result: 6 target: 4
# number: 8608 result: 8 target: 7
# number: 8609 result: 6 target: 8
# number: 8610 result: 6 target: 7
# number: 8611 result: 7 target: 8
# number: 8612 result: 2 target: 7
# number: 8613 result: 7 target: 9
# number: 8614 result: 8 target: 7
# number: 8615 result: 6 target: 7
# number: 8616 result: 3 target: 2
# number: 8617 result: 1 target: 1
# number: 8618 result: 7 target: 8
# number: 8619 result: 1 target: 1
# number: 8620 result: 7 target: 7
# number: 8621 result: 8 target: 2
# number: 8622 result: 6 target: 7
# number: 8623 result: 1 target: 1
# number: 8624 result: 8 target: 8
# number: 8625 result: 6 target: 3
# number: 8626 result: 8 target: 7
# number: 8627 result: 8 target: 10
# number: 8628 result: 1 target: 1
# number: 8629 result: 8 target: 7
# number: 8630 result: 7 target: 8
# number: 8631 result: 1 target: 4
# number: 8632 result: 1 target: 10
# number: 8633 result: 8 target: 8
# number: 8634 result: 8 target: 4
# number: 8635 result: 7 target: 10
# number: 8636 result: 7 target: 10
# number: 8637 result: 8 target: 7
# number: 8638 result: 1 target: 8
# number: 8639 result: 1 target: 1
# number: 8640 result: 8 target: 8
# number: 8641 result: 1 target: 3
# number: 8642 result: 1 target: 1
# number: 8643 result: 6 target: 9
# number: 8644 result: 7 target: 10
# number: 8645 result: 7 target: 10
# number: 8646 result: 7 target: 10
# number: 8647 result: 7 target: 9
# number: 8648 result: 0 target: 1
# number: 8649 result: 6 target: 7
# number: 8650 result: 1 target: 3
# number: 8651 result: 1 target: 3
# number: 8652 result: 7 target: 8
# number: 8653 result: 1 target: 10
# number: 8654 result: 6 target: 9
# number: 8655 result: 8 target: 10
# number: 8656 result: 1 target: 1
# number: 8657 result: 1 target: 1
# number: 8658 result: 1 target: 8
# number: 8659 result: 6 target: 2
# number: 8660 result: 7 target: 10
# number: 8661 result: 8 target: 9
# number: 8662 result: 1 target: 10
# number: 8663 result: 1 target: 1
# number: 8664 result: 7 target: 10
# number: 8665 result: 1 target: 1
# number: 8666 result: 7 target: 10
# number: 8667 result: 1 target: 3
# number: 8668 result: 1 target: 7
# number: 8669 result: 1 target: 1
# number: 8670 result: 1 target: 1
# number: 8671 result: 1 target: 1
# number: 8672 result: 8 target: 9
# number: 8673 result: 1 target: 3
# number: 8674 result: 1 target: 10
# number: 8675 result: 7 target: 8
# number: 8676 result: 0 target: 3
# number: 8677 result: 1 target: 1
# number: 8678 result: 8 target: 10
# number: 8679 result: 7 target: 10
# number: 8680 result: 6 target: 9
# number: 8681 result: 6 target: 10
# number: 8682 result: 8 target: 8
# number: 8683 result: 1 target: 1
# number: 8684 result: 0 target: 3
# number: 8685 result: 6 target: 8
# number: 8686 result: 7 target: 10
# number: 8687 result: 1 target: 7
# number: 8688 result: 6 target: 7
# number: 8689 result: 6 target: 8
# number: 8690 result: 6 target: 8
# number: 8691 result: 6 target: 9
# number: 8692 result: 6 target: 8
# number: 8693 result: 1 target: 3
# number: 8694 result: 1 target: 2
# number: 8695 result: 1 target: 1
# number: 8696 result: 1 target: 2
# number: 8697 result: 8 target: 10
# number: 8698 result: 1 target: 4
# number: 8699 result: 1 target: 3
# 0.8240229885057472
# number: 8700 result: 6 target: 9
# number: 8701 result: 1 target: 1
# number: 8702 result: 6 target: 10
# number: 8703 result: 8 target: 10
# number: 8704 result: 1 target: 8
# number: 8705 result: 6 target: 10
# number: 8706 result: 3 target: 9
# number: 8707 result: 3 target: 3
# number: 8708 result: 1 target: 3
# number: 8709 result: 7 target: 10
# number: 8710 result: 1 target: 2
# number: 8711 result: 1 target: 2
# number: 8712 result: 1 target: 1
# number: 8713 result: 1 target: 4
# number: 8714 result: 7 target: 10
# number: 8715 result: 3 target: 4
# number: 8716 result: 1 target: 4
# number: 8717 result: 1 target: 1
# number: 8718 result: 8 target: 8
# number: 8719 result: 0 target: 1
# number: 8720 result: 1 target: 1
# number: 8721 result: 7 target: 10
# number: 8722 result: 6 target: 8
# number: 8723 result: 7 target: 7
# number: 8724 result: 0 target: 1
# number: 8725 result: 8 target: 10
# number: 8726 result: 1 target: 4
# number: 8727 result: 1 target: 4
# number: 8728 result: 1 target: 7
# number: 8729 result: 8 target: 9
# number: 8730 result: 8 target: 10
# number: 8731 result: 8 target: 9
# number: 8732 result: 0 target: 3
# number: 8733 result: 0 target: 3
# number: 8734 result: 1 target: 1
# number: 8735 result: 1 target: 7
# number: 8736 result: 1 target: 1
# number: 8737 result: 1 target: 2
# number: 8738 result: 6 target: 10
# number: 8739 result: 6 target: 7
# number: 8740 result: 6 target: 3
# number: 8741 result: 6 target: 7
# number: 8742 result: 8 target: 7
# number: 8743 result: 8 target: 8
# number: 8744 result: 8 target: 10
# number: 8745 result: 8 target: 10
# number: 8746 result: 1 target: 4
# number: 8747 result: 3 target: 1
# number: 8748 result: 3 target: 4
# number: 8749 result: 0 target: 1
# number: 8750 result: 1 target: 1
# number: 8751 result: 1 target: 2
# number: 8752 result: 3 target: 3
# number: 8753 result: 7 target: 1
# number: 8754 result: 8 target: 4
# number: 8755 result: 8 target: 10
# number: 8756 result: 0 target: 1
# number: 8757 result: 7 target: 10
# number: 8758 result: 1 target: 8
# number: 8759 result: 1 target: 1
# number: 8760 result: 6 target: 9
# number: 8761 result: 1 target: 8
# number: 8762 result: 1 target: 1
# number: 8763 result: 1 target: 1
# number: 8764 result: 6 target: 3
# number: 8765 result: 1 target: 1
# number: 8766 result: 8 target: 10
# number: 8767 result: 8 target: 9
# number: 8768 result: 1 target: 1
# number: 8769 result: 1 target: 4
# number: 8770 result: 6 target: 7
# number: 8771 result: 1 target: 2
# number: 8772 result: 1 target: 2
# number: 8773 result: 8 target: 10
# number: 8774 result: 7 target: 10
# number: 8775 result: 1 target: 7
# number: 8776 result: 1 target: 1
# number: 8777 result: 8 target: 10
# number: 8778 result: 1 target: 1
# number: 8779 result: 7 target: 10
# number: 8780 result: 8 target: 10
# number: 8781 result: 1 target: 1
# number: 8782 result: 1 target: 1
# number: 8783 result: 7 target: 4
# number: 8784 result: 1 target: 10
# number: 8785 result: 1 target: 2
# number: 8786 result: 3 target: 9
# number: 8787 result: 8 target: 1
# number: 8788 result: 1 target: 1
# number: 8789 result: 1 target: 10
# number: 8790 result: 0 target: 1
# number: 8791 result: 1 target: 10
# number: 8792 result: 1 target: 1
# number: 8793 result: 7 target: 8
# number: 8794 result: 3 target: 3
# number: 8795 result: 1 target: 1
# number: 8796 result: 8 target: 10
# number: 8797 result: 1 target: 1
# number: 8798 result: 7 target: 8
# number: 8799 result: 0 target: 3
# 0.8240909090909091
# number: 8800 result: 8 target: 8
# number: 8801 result: 2 target: 4
# number: 8802 result: 6 target: 8
# number: 8803 result: 6 target: 7
# number: 8804 result: 6 target: 4
# number: 8805 result: 8 target: 10
# number: 8806 result: 8 target: 10
# number: 8807 result: 6 target: 4
# number: 8808 result: 7 target: 9
# number: 8809 result: 1 target: 3
# number: 8810 result: 3 target: 4
# number: 8811 result: 3 target: 1
# number: 8812 result: 1 target: 1
# number: 8813 result: 8 target: 8
# number: 8814 result: 0 target: 3
# number: 8815 result: 7 target: 10
# number: 8816 result: 1 target: 1
# number: 8817 result: 3 target: 3
# number: 8818 result: 7 target: 9
# number: 8819 result: 6 target: 10
# number: 8820 result: 1 target: 1
# number: 8821 result: 1 target: 3
# number: 8822 result: 7 target: 1
# number: 8823 result: 8 target: 8
# number: 8824 result: 1 target: 9
# number: 8825 result: 8 target: 10
# number: 8826 result: 0 target: 2
# number: 8827 result: 8 target: 7
# number: 8828 result: 6 target: 8
# number: 8829 result: 8 target: 10
# number: 8830 result: 7 target: 10
# number: 8831 result: 8 target: 10
# number: 8832 result: 1 target: 9
# number: 8833 result: 1 target: 1
# number: 8834 result: 8 target: 8
# number: 8835 result: 1 target: 3
# number: 8836 result: 6 target: 8
# number: 8837 result: 6 target: 9
# number: 8838 result: 6 target: 4
# number: 8839 result: 1 target: 2
# number: 8840 result: 0 target: 1
# number: 8841 result: 3 target: 4
# number: 8842 result: 8 target: 3
# number: 8843 result: 3 target: 1
# number: 8844 result: 3 target: 4
# number: 8845 result: 1 target: 1
# number: 8846 result: 6 target: 10
# number: 8847 result: 1 target: 4
# number: 8848 result: 1 target: 1
# number: 8849 result: 7 target: 10
# number: 8850 result: 8 target: 8
# number: 8851 result: 0 target: 4
# number: 8852 result: 1 target: 8
# number: 8853 result: 1 target: 1
# number: 8854 result: 1 target: 1
# number: 8855 result: 1 target: 1
# number: 8856 result: 8 target: 1
# number: 8857 result: 3 target: 3
# number: 8858 result: 1 target: 1
# number: 8859 result: 7 target: 8
# number: 8860 result: 8 target: 7
# number: 8861 result: 0 target: 1
# number: 8862 result: 8 target: 8
# number: 8863 result: 0 target: 7
# number: 8864 result: 8 target: 10
# number: 8865 result: 7 target: 10
# number: 8866 result: 1 target: 9
# number: 8867 result: 0 target: 4
# number: 8868 result: 8 target: 8
# number: 8869 result: 1 target: 3
# number: 8870 result: 1 target: 3
# number: 8871 result: 6 target: 4
# number: 8872 result: 8 target: 3
# number: 8873 result: 1 target: 1
# number: 8874 result: 8 target: 7
# number: 8875 result: 6 target: 9
# number: 8876 result: 8 target: 9
# number: 8877 result: 1 target: 3
# number: 8878 result: 8 target: 10
# number: 8879 result: 1 target: 4
# number: 8880 result: 7 target: 3
# number: 8881 result: 1 target: 4
# number: 8882 result: 1 target: 1
# number: 8883 result: 0 target: 1
# number: 8884 result: 1 target: 2
# number: 8885 result: 7 target: 10
# number: 8886 result: 8 target: 10
# number: 8887 result: 1 target: 1
# number: 8888 result: 8 target: 10
# number: 8889 result: 1 target: 4
# number: 8890 result: 8 target: 1
# number: 8891 result: 3 target: 3
# number: 8892 result: 1 target: 4
# number: 8893 result: 8 target: 3
# number: 8894 result: 1 target: 1
# number: 8895 result: 8 target: 4
# number: 8896 result: 3 target: 3
# number: 8897 result: 8 target: 10
# number: 8898 result: 6 target: 2
# number: 8899 result: 8 target: 10
# 0.8239325842696629
# number: 8900 result: 3 target: 7
# number: 8901 result: 3 target: 3
# number: 8902 result: 7 target: 9
# number: 8903 result: 6 target: 8
# number: 8904 result: 6 target: 7
# number: 8905 result: 8 target: 10
# number: 8906 result: 3 target: 2
# number: 8907 result: 6 target: 7
# number: 8908 result: 1 target: 1
# number: 8909 result: 8 target: 8
# number: 8910 result: 1 target: 8
# number: 8911 result: 8 target: 10
# number: 8912 result: 1 target: 1
# number: 8913 result: 7 target: 9
# number: 8914 result: 6 target: 7
# number: 8915 result: 1 target: 1
# number: 8916 result: 6 target: 9
# number: 8917 result: 8 target: 10
# number: 8918 result: 1 target: 1
# number: 8919 result: 0 target: 1
# number: 8920 result: 1 target: 9
# number: 8921 result: 0 target: 8
# number: 8922 result: 6 target: 7
# number: 8923 result: 1 target: 2
# number: 8924 result: 8 target: 10
# number: 8925 result: 7 target: 10
# number: 8926 result: 3 target: 2
# number: 8927 result: 8 target: 7
# number: 8928 result: 1 target: 9
# number: 8929 result: 1 target: 4
# number: 8930 result: 8 target: 10
# number: 8931 result: 8 target: 1
# number: 8932 result: 7 target: 8
# number: 8933 result: 7 target: 8
# number: 8934 result: 6 target: 8
# number: 8935 result: 1 target: 3
# number: 8936 result: 2 target: 2
# number: 8937 result: 8 target: 1
# number: 8938 result: 1 target: 2
# number: 8939 result: 7 target: 10
# number: 8940 result: 2 target: 3
# number: 8941 result: 8 target: 7
# number: 8942 result: 7 target: 10
# number: 8943 result: 7 target: 10
# number: 8944 result: 7 target: 10
# number: 8945 result: 1 target: 2
# number: 8946 result: 8 target: 10
# number: 8947 result: 1 target: 1
# number: 8948 result: 1 target: 1
# number: 8949 result: 8 target: 9
# number: 8950 result: 6 target: 7
# number: 8951 result: 7 target: 8
# number: 8952 result: 8 target: 10
# number: 8953 result: 6 target: 7
# number: 8954 result: 7 target: 10
# number: 8955 result: 1 target: 3
# number: 8956 result: 1 target: 1
# number: 8957 result: 7 target: 9
# number: 8958 result: 1 target: 10
# number: 8959 result: 8 target: 7
# number: 8960 result: 8 target: 4
# number: 8961 result: 6 target: 7
# number: 8962 result: 1 target: 3
# number: 8963 result: 0 target: 8
# number: 8964 result: 1 target: 1
# number: 8965 result: 8 target: 10
# number: 8966 result: 8 target: 10
# number: 8967 result: 3 target: 4
# number: 8968 result: 1 target: 2
# number: 8969 result: 8 target: 9
# number: 8970 result: 3 target: 4
# number: 8971 result: 6 target: 9
# number: 8972 result: 8 target: 9
# number: 8973 result: 3 target: 1
# number: 8974 result: 8 target: 9
# number: 8975 result: 8 target: 1
# number: 8976 result: 3 target: 7
# number: 8977 result: 3 target: 3
# number: 8978 result: 8 target: 10
# number: 8979 result: 3 target: 9
# number: 8980 result: 8 target: 8
# number: 8981 result: 6 target: 7
# number: 8982 result: 1 target: 1
# number: 8983 result: 7 target: 9
# number: 8984 result: 8 target: 10
# number: 8985 result: 1 target: 1
# ...
# number: 12035 result: 1 target: 1
# number: 12036 result: 0 target: 1
# number: 12037 result: 1 target: 3
# number: 12038 result: 7 target: 10
# number: 12039 result: 1 target: 1
# number: 12040 result: 1 target: 10
# number: 12041 result: 3 target: 4
# number: 12042 result: 6 target: 7
# number: 12043 result: 8 target: 9
# number: 12044 result: 8 target: 9
# number: 12045 result: 0 target: 8
# number: 12046 result: 8 target: 9
# number: 12047 result: 7 target: 10
# number: 12048 result: 1 target: 1
# number: 12049 result: 1 target: 10
# number: 12050 result: 7 target: 7
# number: 12051 result: 2 target: 1
# number: 12052 result: 6 target: 4
# number: 12053 result: 1 target: 8
# number: 12054 result: 8 target: 8
# number: 12055 result: 1 target: 1
# number: 12056 result: 1 target: 1
# number: 12057 result: 6 target: 4
# number: 12058 result: 7 target: 10
# number: 12059 result: 6 target: 7
# number: 12060 result: 1 target: 7
# number: 12061 result: 8 target: 10
# number: 12062 result: 3 target: 4
# number: 12063 result: 6 target: 2
# number: 12064 result: 8 target: 10
# number: 12065 result: 1 target: 1
# number: 12066 result: 0 target: 2
# number: 12067 result: 8 target: 9
# number: 12068 result: 2 target: 2
# number: 12069 result: 6 target: 8
# number: 12070 result: 1 target: 4
# number: 12071 result: 0 target: 1
# number: 12072 result: 8 target: 8
# number: 12073 result: 1 target: 3
# number: 12074 result: 1 target: 1
# number: 12075 result: 0 target: 3
# number: 12076 result: 1 target: 1
# number: 12077 result: 1 target: 10
# number: 12078 result: 1 target: 2
# number: 12079 result: 1 target: 2
# number: 12080 result: 1 target: 4
# number: 12081 result: 7 target: 10
# number: 12082 result: 1 target: 1
# number: 12083 result: 8 target: 4
# number: 12084 result: 0 target: 1
# number: 12085 result: 1 target: 1
# number: 12086 result: 1 target: 1
# number: 12087 result: 1 target: 2
# number: 12088 result: 2 target: 7
# number: 12089 result: 7 target: 9
# number: 12090 result: 2 target: 9
# number: 12091 result: 7 target: 7
# number: 12092 result: 6 target: 3
# number: 12093 result: 6 target: 8
# number: 12094 result: 6 target: 9
# number: 12095 result: 3 target: 10
# number: 12096 result: 1 target: 1
# number: 12097 result: 8 target: 10
# number: 12098 result: 8 target: 8
# number: 12099 result: 7 target: 7
# 0.824297520661157
# number: 12100 result: 2 target: 2
# number: 12101 result: 6 target: 9
# number: 12102 result: 1 target: 1
# number: 12103 result: 0 target: 7
# number: 12104 result: 1 target: 2
# number: 12105 result: 3 target: 8
# number: 12106 result: 6 target: 10
# number: 12107 result: 7 target: 10
# number: 12108 result: 3 target: 8
# number: 12109 result: 0 target: 10
# number: 12110 result: 1 target: 7
# number: 12111 result: 8 target: 7
# number: 12112 result: 6 target: 10
# number: 12113 result: 7 target: 9
# number: 12114 result: 1 target: 3
# number: 12115 result: 2 target: 3
# number: 12116 result: 0 target: 1
# number: 12117 result: 0 target: 4
# number: 12118 result: 2 target: 7
# number: 12119 result: 8 target: 7
# number: 12120 result: 3 target: 8
# number: 12121 result: 7 target: 10
# number: 12122 result: 0 target: 8
# number: 12123 result: 8 target: 7
# number: 12124 result: 8 target: 8
# number: 12125 result: 7 target: 4
# number: 12126 result: 7 target: 10
# number: 12127 result: 0 target: 4
# number: 12128 result: 8 target: 7
# number: 12129 result: 1 target: 1
# number: 12130 result: 3 target: 4
# number: 12131 result: 8 target: 10
# number: 12132 result: 8 target: 9
# number: 12133 result: 0 target: 10
# number: 12134 result: 0 target: 2
# number: 12135 result: 7 target: 10
# number: 12136 result: 3 target: 3
# number: 12137 result: 8 target: 10
# number: 12138 result: 8 target: 10
# number: 12139 result: 0 target: 1
# number: 12140 result: 3 target: 8
# number: 12141 result: 0 target: 1
# number: 12142 result: 7 target: 9
# number: 12143 result: 0 target: 10
# number: 12144 result: 8 target: 10
# number: 12145 result: 8 target: 7
# number: 12146 result: 1 target: 2
# number: 12147 result: 6 target: 10
# number: 12148 result: 0 target: 10
# number: 12149 result: 8 target: 10
# number: 12150 result: 1 target: 1
# number: 12151 result: 8 target: 8
# number: 12152 result: 1 target: 1
# number: 12153 result: 2 target: 9
# number: 12154 result: 8 target: 10
# number: 12155 result: 2 target: 4
# number: 12156 result: 1 target: 1
# number: 12157 result: 1 target: 1
# number: 12158 result: 1 target: 1
# number: 12159 result: 8 target: 10
# number: 12160 result: 7 target: 8
# number: 12161 result: 6 target: 9
# number: 12162 result: 1 target: 1
# number: 12163 result: 1 target: 3
# number: 12164 result: 3 target: 7
# number: 12165 result: 1 target: 2
# number: 12166 result: 2 target: 8
# number: 12167 result: 1 target: 4
# number: 12168 result: 7 target: 10
# number: 12169 result: 1 target: 4
# number: 12170 result: 1 target: 8
# number: 12171 result: 3 target: 7
# number: 12172 result: 7 target: 10
# number: 12173 result: 0 target: 1
# number: 12174 result: 7 target: 8
# number: 12175 result: 1 target: 1
# number: 12176 result: 0 target: 3
# number: 12177 result: 8 target: 4
# number: 12178 result: 1 target: 1
# number: 12179 result: 8 target: 10
# number: 12180 result: 7 target: 4
# number: 12181 result: 8 target: 9
# number: 12182 result: 6 target: 8
# number: 12183 result: 1 target: 1
# number: 12184 result: 1 target: 3
# number: 12185 result: 1 target: 3
# number: 12186 result: 1 target: 1
# number: 12187 result: 1 target: 3
# number: 12188 result: 0 target: 1
# number: 12189 result: 6 target: 7
# number: 12190 result: 2 target: 9
# number: 12191 result: 7 target: 10
# number: 12192 result: 3 target: 4
# number: 12193 result: 1 target: 1
# number: 12194 result: 1 target: 8
# number: 12195 result: 3 target: 1
# number: 12196 result: 8 target: 10
# number: 12197 result: 8 target: 10
# number: 12198 result: 1 target: 7
# number: 12199 result: 7 target: 9
# 0.8238524590163935
# number: 12200 result: 2 target: 3
# number: 12201 result: 1 target: 4
# number: 12202 result: 1 target: 1
# number: 12203 result: 7 target: 8
# number: 12204 result: 1 target: 3
# number: 12205 result: 8 target: 2
# number: 12206 result: 1 target: 1
# number: 12207 result: 6 target: 8
# number: 12208 result: 6 target: 10
# number: 12209 result: 0 target: 3
# number: 12210 result: 2 target: 2
# number: 12211 result: 1 target: 1
# number: 12212 result: 7 target: 8
# number: 12213 result: 8 target: 8
# number: 12214 result: 1 target: 4
# number: 12215 result: 8 target: 8
# number: 12216 result: 0 target: 1
# number: 12217 result: 8 target: 10
# number: 12218 result: 1 target: 7
# number: 12219 result: 1 target: 4
# number: 12220 result: 7 target: 10
# number: 12221 result: 1 target: 1
# number: 12222 result: 0 target: 1
# number: 12223 result: 1 target: 2
# number: 12224 result: 1 target: 4
# number: 12225 result: 3 target: 8
# number: 12226 result: 7 target: 4
# number: 12227 result: 8 target: 10
# number: 12228 result: 2 target: 7
# number: 12229 result: 1 target: 8
# number: 12230 result: 6 target: 10
# number: 12231 result: 7 target: 10
# number: 12232 result: 1 target: 7
# number: 12233 result: 0 target: 8
# number: 12234 result: 8 target: 10
# number: 12235 result: 1 target: 1
# number: 12236 result: 6 target: 9
# number: 12237 result: 8 target: 10
# number: 12238 result: 3 target: 8
# number: 12239 result: 2 target: 4
# number: 12240 result: 6 target: 10
# number: 12241 result: 8 target: 8
# number: 12242 result: 7 target: 8
# number: 12243 result: 1 target: 1
# number: 12244 result: 1 target: 2
# number: 12245 result: 8 target: 8
# number: 12246 result: 7 target: 10
# number: 12247 result: 0 target: 7
# number: 12248 result: 1 target: 1
# number: 12249 result: 8 target: 9
# number: 12250 result: 1 target: 1
# number: 12251 result: 1 target: 10
# number: 12252 result: 1 target: 1
# number: 12253 result: 0 target: 3
# number: 12254 result: 1 target: 4
# number: 12255 result: 8 target: 1
# number: 12256 result: 7 target: 10
# number: 12257 result: 1 target: 9
# number: 12258 result: 0 target: 3
# number: 12259 result: 1 target: 1
# number: 12260 result: 7 target: 8
# number: 12261 result: 7 target: 9
# number: 12262 result: 6 target: 8
# number: 12263 result: 1 target: 4
# number: 12264 result: 6 target: 8
# number: 12265 result: 8 target: 2
# number: 12266 result: 1 target: 10
# number: 12267 result: 8 target: 10
# number: 12268 result: 1 target: 1
# number: 12269 result: 6 target: 4
# number: 12270 result: 1 target: 1
# number: 12271 result: 8 target: 8
# number: 12272 result: 3 target: 4
# number: 12273 result: 8 target: 3
# number: 12274 result: 7 target: 10
# number: 12275 result: 1 target: 1
# number: 12276 result: 8 target: 10
# number: 12277 result: 1 target: 1
# number: 12278 result: 0 target: 1
# number: 12279 result: 7 target: 10
# number: 12280 result: 1 target: 3
# number: 12281 result: 8 target: 10
# number: 12282 result: 2 target: 7
# number: 12283 result: 6 target: 8
# number: 12284 result: 6 target: 4
# number: 12285 result: 8 target: 10
# number: 12286 result: 1 target: 1
# number: 12287 result: 1 target: 1
# number: 12288 result: 7 target: 9
# number: 12289 result: 8 target: 10
# number: 12290 result: 1 target: 1
# number: 12291 result: 8 target: 7
# number: 12292 result: 8 target: 7
# number: 12293 result: 1 target: 1
# number: 12294 result: 1 target: 1
# number: 12295 result: 1 target: 1
# number: 12296 result: 1 target: 1
# number: 12297 result: 8 target: 7
# number: 12298 result: 8 target: 8
# number: 12299 result: 1 target: 3
# 0.823739837398374
# number: 12300 result: 7 target: 10
# number: 12301 result: 1 target: 1
# number: 12302 result: 1 target: 7
# number: 12303 result: 1 target: 1
# number: 12304 result: 8 target: 7
# number: 12305 result: 6 target: 3
# number: 12306 result: 1 target: 1
# number: 12307 result: 0 target: 4
# number: 12308 result: 1 target: 1
# number: 12309 result: 1 target: 2
# number: 12310 result: 1 target: 4
# number: 12311 result: 1 target: 8
# number: 12312 result: 0 target: 9
# number: 12313 result: 1 target: 1
# number: 12314 result: 6 target: 10
# number: 12315 result: 1 target: 7
# number: 12316 result: 6 target: 1
# number: 12317 result: 3 target: 7
# number: 12318 result: 7 target: 10
# number: 12319 result: 1 target: 1
# number: 12320 result: 1 target: 1
# number: 12321 result: 1 target: 3
# number: 12322 result: 1 target: 10
# number: 12323 result: 1 target: 1
# number: 12324 result: 3 target: 7
# number: 12325 result: 6 target: 8
# number: 12326 result: 0 target: 3
# number: 12327 result: 0 target: 2
# number: 12328 result: 1 target: 1
# number: 12329 result: 6 target: 10
# number: 12330 result: 0 target: 4
# number: 12331 result: 1 target: 7
# number: 12332 result: 7 target: 8
# number: 12333 result: 7 target: 1
# number: 12334 result: 6 target: 10
# number: 12335 result: 6 target: 8
# number: 12336 result: 1 target: 2
# number: 12337 result: 8 target: 10
# number: 12338 result: 1 target: 1
# number: 12339 result: 7 target: 3
# number: 12340 result: 8 target: 10
# number: 12341 result: 7 target: 10
# number: 12342 result: 0 target: 10
# number: 12343 result: 6 target: 10
# number: 12344 result: 8 target: 3
# number: 12345 result: 6 target: 10
# number: 12346 result: 0 target: 1
# number: 12347 result: 7 target: 9
# number: 12348 result: 7 target: 2
# number: 12349 result: 1 target: 3
# number: 12350 result: 7 target: 7
# number: 12351 result: 1 target: 4
# number: 12352 result: 7 target: 10
# number: 12353 result: 1 target: 1
# number: 12354 result: 1 target: 3
# number: 12355 result: 1 target: 1
# number: 12356 result: 1 target: 4
# number: 12357 result: 3 target: 3
# number: 12358 result: 1 target: 1
# number: 12359 result: 1 target: 3
# number: 12360 result: 1 target: 1
# number: 12361 result: 1 target: 1
# number: 12362 result: 8 target: 4
# number: 12363 result: 8 target: 7
# number: 12364 result: 3 target: 2
# number: 12365 result: 1 target: 1
# number: 12366 result: 8 target: 9
# number: 12367 result: 0 target: 1
# number: 12368 result: 1 target: 1
# number: 12369 result: 1 target: 7
# number: 12370 result: 8 target: 9
# number: 12371 result: 2 target: 3
# number: 12372 result: 8 target: 8
# number: 12373 result: 3 target: 7
# number: 12374 result: 8 target: 7
# number: 12375 result: 0 target: 10
# number: 12376 result: 7 target: 4
# number: 12377 result: 8 target: 7
# number: 12378 result: 1 target: 1
# number: 12379 result: 1 target: 8
# number: 12380 result: 0 target: 4
# number: 12381 result: 0 target: 2
# number: 12382 result: 8 target: 8
# number: 12383 result: 0 target: 1
# number: 12384 result: 8 target: 9
# number: 12385 result: 6 target: 10
# number: 12386 result: 1 target: 1
# number: 12387 result: 6 target: 10
# number: 12388 result: 3 target: 4
# number: 12389 result: 1 target: 1
# number: 12390 result: 7 target: 2
# number: 12391 result: 8 target: 9
# number: 12392 result: 2 target: 9
# number: 12393 result: 8 target: 10
# number: 12394 result: 8 target: 10
# number: 12395 result: 8 target: 4
# number: 12396 result: 7 target: 10
# number: 12397 result: 1 target: 1
# number: 12398 result: 8 target: 10
# number: 12399 result: 0 target: 10
# 0.8231451612903226
# number: 12400 result: 1 target: 3
# number: 12401 result: 3 target: 3
# number: 12402 result: 1 target: 10
# number: 12403 result: 1 target: 4
# number: 12404 result: 1 target: 7
# number: 12405 result: 1 target: 7
# number: 12406 result: 7 target: 4
# number: 12407 result: 8 target: 10
# number: 12408 result: 1 target: 4
# number: 12409 result: 3 target: 3
# number: 12410 result: 8 target: 10
# number: 12411 result: 8 target: 8
# number: 12412 result: 1 target: 1
# number: 12413 result: 8 target: 7
# number: 12414 result: 8 target: 9
# number: 12415 result: 8 target: 7
# number: 12416 result: 6 target: 10
# number: 12417 result: 7 target: 8
# number: 12418 result: 7 target: 10
# number: 12419 result: 1 target: 1
# number: 12420 result: 8 target: 10
# number: 12421 result: 7 target: 7
# number: 12422 result: 1 target: 2
# number: 12423 result: 0 target: 3
# number: 12424 result: 3 target: 3
# number: 12425 result: 1 target: 1
# number: 12426 result: 3 target: 4
# number: 12427 result: 6 target: 4
# number: 12428 result: 3 target: 3
# number: 12429 result: 3 target: 3
# number: 12430 result: 1 target: 2
# number: 12431 result: 8 target: 9
# number: 12432 result: 1 target: 1
# number: 12433 result: 1 target: 1
# number: 12434 result: 8 target: 10
# number: 12435 result: 6 target: 4
# number: 12436 result: 8 target: 8
# number: 12437 result: 8 target: 8
# number: 12438 result: 0 target: 1
# number: 12439 result: 3 target: 7
# number: 12440 result: 7 target: 9
# number: 12441 result: 1 target: 2
# number: 12442 result: 3 target: 2
# number: 12443 result: 7 target: 10
# number: 12444 result: 0 target: 2
# number: 12445 result: 1 target: 1
# number: 12446 result: 6 target: 1
# number: 12447 result: 1 target: 2
# number: 12448 result: 7 target: 10
# number: 12449 result: 1 target: 1
# number: 12450 result: 6 target: 8
# number: 12451 result: 1 target: 3
# number: 12452 result: 8 target: 9
# number: 12453 result: 1 target: 3
# number: 12454 result: 1 target: 3
# number: 12455 result: 1 target: 1
# number: 12456 result: 3 target: 9
# number: 12457 result: 8 target: 1
# number: 12458 result: 7 target: 9
# number: 12459 result: 0 target: 2
# number: 12460 result: 1 target: 4
# number: 12461 result: 7 target: 8
# number: 12462 result: 0 target: 4
# number: 12463 result: 1 target: 10
# number: 12464 result: 7 target: 10
# number: 12465 result: 7 target: 10
# number: 12466 result: 7 target: 10
# number: 12467 result: 8 target: 7
# number: 12468 result: 1 target: 3
# number: 12469 result: 7 target: 9
# number: 12470 result: 8 target: 10
# number: 12471 result: 8 target: 10
# number: 12472 result: 0 target: 4
# number: 12473 result: 1 target: 1
# number: 12474 result: 1 target: 1
# number: 12475 result: 7 target: 7
# number: 12476 result: 1 target: 2
# number: 12477 result: 1 target: 1
# number: 12478 result: 1 target: 1
# number: 12479 result: 8 target: 9
# number: 12480 result: 3 target: 9
# number: 12481 result: 1 target: 2
# number: 12482 result: 1 target: 3
# number: 12483 result: 1 target: 3
# number: 12484 result: 1 target: 1
# number: 12485 result: 1 target: 8
# number: 12486 result: 1 target: 1
# number: 12487 result: 7 target: 8
# number: 12488 result: 1 target: 1
# number: 12489 result: 3 target: 3
# number: 12490 result: 3 target: 1
# number: 12491 result: 1 target: 1
# number: 12492 result: 7 target: 9
# number: 12493 result: 0 target: 2
# number: 12494 result: 1 target: 7
# number: 12495 result: 8 target: 10
# number: 12496 result: 7 target: 10
# number: 12497 result: 7 target: 1
# number: 12498 result: 1 target: 1
# number: 12499 result: 7 target: 7
# 0.82328
